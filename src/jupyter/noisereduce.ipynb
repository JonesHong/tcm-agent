# %% [markdown]
# # 用 noisereduce 進行降噪
# 同時保存原始聲音、降噪音檔

# %%
import pyaudio
import noisereduce as nr
import numpy as np
import wave

# 設置音頻流參數
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 44100
CHUNK = 1024
RECORD_SECONDS = 10
OUTPUT_FILENAME_ORIGINAL = "output_original.wav"
OUTPUT_FILENAME_REDUCED = "output_reduced.wav"

p = pyaudio.PyAudio()

# 打開音頻流
stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK)

print("開始錄音...")

frames_original = []
frames_reduced = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames_original.append(data)
    audio_data = np.frombuffer(data, dtype=np.int16)
    reduced_noise = nr.reduce_noise(y=audio_data, sr=RATE, prop_decrease=1.0, n_std_thresh_stationary=1.5)
    frames_reduced.append(reduced_noise.tobytes())

print("錄音結束...")

# 停止和關閉音頻流
stream.stop_stream()
stream.close()
p.terminate()

# 保存原始音頻數據到文件
wf_original = wave.open(OUTPUT_FILENAME_ORIGINAL, 'wb')
wf_original.setnchannels(CHANNELS)
wf_original.setsampwidth(p.get_sample_size(FORMAT))
wf_original.setframerate(RATE)
wf_original.writeframes(b''.join(frames_original))
wf_original.close()

# 保存降噪後的音頻數據到文件
wf_reduced = wave.open(OUTPUT_FILENAME_REDUCED, 'wb')
wf_reduced.setnchannels(CHANNELS)
wf_reduced.setsampwidth(p.get_sample_size(FORMAT))
wf_reduced.setframerate(RATE)
wf_reduced.writeframes(b''.join(frames_reduced))
wf_reduced.close()

print(f"原始音頻已保存到 {OUTPUT_FILENAME_ORIGINAL}")
print(f"降噪後的音頻已保存到 {OUTPUT_FILENAME_REDUCED}")
# Out:
# 開始錄音...
# 錄音結束...
# 原始音頻已保存到 output_original.wav
# 降噪後的音頻已保存到 output_reduced.wav

# %% [markdown]
# # 用 noisereduce 進行降噪
# 先保存原始聲音，在對聲音降噪後另存降噪音檔

# %%
import pyaudio
import noisereduce as nr
import numpy as np
import wave

# 設置音頻流參數
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 44100
CHUNK = 1024
RECORD_SECONDS = 10
OUTPUT_FILENAME_ORIGINAL = "output_original.wav"
OUTPUT_FILENAME_REDUCED = "output_reduced.wav"

p = pyaudio.PyAudio()

# 打開音頻流
stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK)

print("開始錄音...")

frames_original = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames_original.append(data)

print("錄音結束...")

# 停止和關閉音頻流
stream.stop_stream()
stream.close()
p.terminate()

# 保存原始音頻數據到文件
wf_original = wave.open(OUTPUT_FILENAME_ORIGINAL, 'wb')
wf_original.setnchannels(CHANNELS)
wf_original.setsampwidth(p.get_sample_size(FORMAT))
wf_original.setframerate(RATE)
wf_original.writeframes(b''.join(frames_original))
wf_original.close()

print(f"原始音頻已保存到 {OUTPUT_FILENAME_ORIGINAL}")

# 進行降噪處理並保存降噪後的音頻數據到文件
wf_reduced = wave.open(OUTPUT_FILENAME_REDUCED, 'wb')
wf_reduced.setnchannels(CHANNELS)
wf_reduced.setsampwidth(p.get_sample_size(FORMAT))
wf_reduced.setframerate(RATE)

for frame in frames_original:
    audio_data = np.frombuffer(frame, dtype=np.int16)
    reduced_noise = nr.reduce_noise(y=audio_data, sr=RATE, prop_decrease=1.0, n_std_thresh_stationary=1.5)
    wf_reduced.writeframes(reduced_noise.tobytes())

wf_reduced.close()

print(f"降噪後的音頻已保存到 {OUTPUT_FILENAME_REDUCED}")
# Out:
# 開始錄音...
# 錄音結束...
# 原始音頻已保存到 output_original.wav
# 降噪後的音頻已保存到 output_reduced.wav

# %% [markdown]
# # 用 scipy 進行降噪

# %%
import pyaudio
import numpy as np
import wave
import librosa
import scipy

# 設置音頻流參數
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 44100
CHUNK = 1024
RECORD_SECONDS = 10
OUTPUT_FILENAME_ORIGINAL = "output_original.wav"
OUTPUT_FILENAME_REDUCED = "output_reduced.wav"

p = pyaudio.PyAudio()

# 打開音頻流
stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK)

print("開始錄音...")

frames_original = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames_original.append(data)

print("錄音結束...")

# 停止和關閉音頻流
stream.stop_stream()
stream.close()
p.terminate()

# 保存原始音頻數據到文件
wf_original = wave.open(OUTPUT_FILENAME_ORIGINAL, 'wb')
wf_original.setnchannels(CHANNELS)
wf_original.setsampwidth(p.get_sample_size(FORMAT))
wf_original.setframerate(RATE)
wf_original.writeframes(b''.join(frames_original))
wf_original.close()

# 將原始音頻數據轉換為 numpy 數組
audio_data = np.frombuffer(b''.join(frames_original), dtype=np.int16)

# 使用 librosa 讀取音頻數據並進行降噪處理
y = librosa.util.buf_to_float(audio_data, n_bytes=2, dtype=np.float32)
y_denoised = librosa.effects.preemphasis(y)

# 使用 scipy 將降噪後的數據轉換回原始格式
y_denoised_int16 = (y_denoised * 32767).astype(np.int16)

# 保存降噪後的音頻數據到文件
wf_reduced = wave.open(OUTPUT_FILENAME_REDUCED, 'wb')
wf_reduced.setnchannels(CHANNELS)
wf_reduced.setsampwidth(p.get_sample_size(FORMAT))
wf_reduced.setframerate(RATE)
wf_reduced.writeframes(y_denoised_int16.tobytes())
wf_reduced.close()

print(f"原始音頻已保存到 {OUTPUT_FILENAME_ORIGINAL}")
print(f"降噪後的音頻已保存到 {OUTPUT_FILENAME_REDUCED}")

# %% [markdown]
# # 用 FFmpeg 進行降噪

# %%
"""
ffmpeg -f dshow -i audio="麥克風 (BLUE Yeti PRO)"  -acodec pcm_s16le output_original.wav
ffmpeg -f dshow -i audio="麥克風 (BLUE Yeti PRO)" -af "afftdn=nf=-25" -acodec pcm_s16le output_reduced.wav
ffmpeg -f dshow -i audio="麥克風 (BLUE Yeti PRO)" -af "afftdn=nf=-80" -acodec pcm_s16le output_reduced_2.wav
"""

# %% [markdown]
# # 用 pyrnnoise 進行降噪

# %%
import pyaudio
import numpy as np
import wave
from pyrnnoise import RNNoise

# 初始化 PyAudio
p = pyaudio.PyAudio()

# 設置音頻流參數
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 48000
CHUNK = 1024  # 每個塊的大小應與 RNNoise 的幀大小一致

# 初始化 RNNoise
rnnoise = RNNoise(RATE)

# 打開音頻流
stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK)

# 打開 WAV 文件進行寫入
raw_wav = wave.open("raw_audio.wav", "wb")
denoised_wav = wave.open("denoised_audio.wav", "wb")

# 設置 WAV 文件參數
raw_wav.setnchannels(CHANNELS)
raw_wav.setsampwidth(p.get_sample_size(FORMAT))
raw_wav.setframerate(RATE)

denoised_wav.setnchannels(CHANNELS)
denoised_wav.setsampwidth(p.get_sample_size(FORMAT))
denoised_wav.setframerate(RATE)

print("開始錄音")

try:
    while True:
        # 從麥克風讀取數據
        data = stream.read(CHUNK)
        
        # 將數據轉換為 NumPy 數組
        audio_chunk = np.frombuffer(data, dtype=np.int16)
        
        # 保存原始音頻數據
        raw_wav.writeframes(data)
        
        # 使用 RNNoise 進行降噪處理
        for vad_prob, denoised_chunk in rnnoise.process_chunk(audio_chunk):
            # 在這裡你可以使用處理後的音頻數據
            # 例如，你可以將其保存或播放
            print(f"VAD 概率: {vad_prob}, 降噪後的幀大小: {len(denoised_chunk)}")
            
            # 將降噪後的數據轉換回字節數據
            denoised_data = denoised_chunk.tobytes()
            
            # 保存降噪後的音頻數據
            denoised_wav.writeframes(denoised_data)
            
            # 示例：直接播放處理後的音頻數據（需要額外配置輸出流）
            # output_stream.write(denoised_data)

except KeyboardInterrupt:
    print("錄音結束")

finally:
    # 停止和關閉音頻流
    stream.stop_stream()
    stream.close()
    p.terminate()
    
    # 關閉 WAV 文件
    raw_wav.close()
    denoised_wav.close()
# Out:
# 開始錄音
# VAD 概率: 0.9823699593544006, 降噪後的幀大小: 480
# VAD 概率: 0.9722340106964111, 降噪後的幀大小: 480
# VAD 概率: 0.9961364269256592, 降噪後的幀大小: 480
# VAD 概率: 0.996465265750885, 降噪後的幀大小: 480
# VAD 概率: 0.9591103196144104, 降噪後的幀大小: 480
# VAD 概率: 0.9941698312759399, 降噪後的幀大小: 480
# VAD 概率: 0.9863289594650269, 降噪後的幀大小: 480
# VAD 概率: 0.9784092903137207, 降噪後的幀大小: 480
# VAD 概率: 0.9746274948120117, 降噪後的幀大小: 480
# VAD 概率: 0.963286280632019, 降噪後的幀大小: 480
# VAD 概率: 0.9260342121124268, 降噪後的幀大小: 480
# VAD 概率: 0.7967579364776611, 降噪後的幀大小: 480
# VAD 概率: 0.5767187476158142, 降噪後的幀大小: 480
# VAD 概率: 0.6638088822364807, 降噪後的幀大小: 480
# VAD 概率: 0.577681839466095, 降噪後的幀大小: 480
# VAD 概率: 0.7058886289596558, 降噪後的幀大小: 480
# VAD 概率: 0.46841952204704285, 降噪後的幀大小: 480
# VAD 概率: 0.295551598072052, 降噪後的幀大小: 480
# VAD 概率: 0.23215386271476746, 降噪後的幀大小: 480
# VAD 概率: 0.17747309803962708, 降噪後的幀大小: 480
# VAD 概率: 0.12466713786125183, 降噪後的幀大小: 480
# VAD 概率: 0.04472199082374573, 降噪後的幀大小: 480
# VAD 概率: 0.04530012607574463, 降噪後的幀大小: 480
# VAD 概率: 0.028403520584106445, 降噪後的幀大小: 480
# VAD 概率: 0.04088538885116577, 降噪後的幀大小: 480
# VAD 概率: 0.16767844557762146, 降噪後的幀大小: 480
# VAD 概率: 0.039733707904815674, 降噪後的幀大小: 480
# VAD 概率: 0.03759518265724182, 降噪後的幀大小: 480
# VAD 概率: 0.018784672021865845, 降噪後的幀大小: 480
# VAD 概率: 0.009950220584869385, 降噪後的幀大小: 480
# VAD 概率: 0.004726022481918335, 降噪後的幀大小: 480
# VAD 概率: 0.002414315938949585, 降噪後的幀大小: 480
# VAD 概率: 0.002174586057662964, 降噪後的幀大小: 480
# VAD 概率: 0.0026027560234069824, 降噪後的幀大小: 480
# VAD 概率: 0.0021805167198181152, 降噪後的幀大小: 480
# VAD 概率: 0.002416074275970459, 降噪後的幀大小: 480
# VAD 概率: 0.012817859649658203, 降噪後的幀大小: 480
# VAD 概率: 0.012871414422988892, 降噪後的幀大小: 480
# VAD 概率: 0.004909694194793701, 降噪後的幀大小: 480
# VAD 概率: 0.0022790729999542236, 降噪後的幀大小: 480
# VAD 概率: 0.0020059049129486084, 降噪後的幀大小: 480
# VAD 概率: 0.0018519163131713867, 降噪後的幀大小: 480
# VAD 概率: 0.0010904669761657715, 降噪後的幀大小: 480
# VAD 概率: 0.001200556755065918, 降噪後的幀大小: 480
# VAD 概率: 0.0009605288505554199, 降噪後的幀大小: 480
# VAD 概率: 0.0007086396217346191, 降噪後的幀大小: 480
# VAD 概率: 0.0006855428218841553, 降噪後的幀大小: 480
# VAD 概率: 0.0008026659488677979, 降噪後的幀大小: 480
# VAD 概率: 0.0008710026741027832, 降噪後的幀大小: 480
# VAD 概率: 0.00091513991355896, 降噪後的幀大小: 480
# VAD 概率: 0.0011255145072937012, 降噪後的幀大小: 480
# VAD 概率: 0.0036388039588928223, 降噪後的幀大小: 480
# VAD 概率: 0.002059251070022583, 降噪後的幀大小: 480
# VAD 概率: 0.002723097801208496, 降噪後的幀大小: 480
# VAD 概率: 0.002789229154586792, 降噪後的幀大小: 480
# VAD 概率: 0.011263251304626465, 降噪後的幀大小: 480
# VAD 概率: 0.05626830458641052, 降噪後的幀大小: 480
# VAD 概率: 0.22056901454925537, 降噪後的幀大小: 480
# VAD 概率: 0.3205391764640808, 降噪後的幀大小: 480
# VAD 概率: 0.20276424288749695, 降噪後的幀大小: 480
# VAD 概率: 0.07470059394836426, 降噪後的幀大小: 480
# VAD 概率: 0.12783652544021606, 降噪後的幀大小: 480
# VAD 概率: 0.8295280933380127, 降噪後的幀大小: 480
# VAD 概率: 0.727921724319458, 降噪後的幀大小: 480
# VAD 概率: 0.5701462626457214, 降噪後的幀大小: 480
# VAD 概率: 0.6558219790458679, 降噪後的幀大小: 480
# VAD 概率: 0.7227551937103271, 降噪後的幀大小: 480
# VAD 概率: 0.8647747039794922, 降噪後的幀大小: 480
# VAD 概率: 0.732852578163147, 降噪後的幀大小: 480
# VAD 概率: 0.4958093762397766, 降噪後的幀大小: 480
# VAD 概率: 0.6810161471366882, 降噪後的幀大小: 480
# VAD 概率: 0.6263383626937866, 降噪後的幀大小: 480
# VAD 概率: 0.662002444267273, 降噪後的幀大小: 480
# VAD 概率: 0.24616685509681702, 降噪後的幀大小: 480
# VAD 概率: 0.2958686351776123, 降噪後的幀大小: 480
# VAD 概率: 0.4896828234195709, 降噪後的幀大小: 480
# VAD 概率: 0.8546249866485596, 降噪後的幀大小: 480
# VAD 概率: 0.9499996900558472, 降噪後的幀大小: 480
# VAD 概率: 0.9594589471817017, 降噪後的幀大小: 480
# VAD 概率: 0.9679757356643677, 降噪後的幀大小: 480
# VAD 概率: 0.9695548415184021, 降噪後的幀大小: 480
# VAD 概率: 0.9664337635040283, 降噪後的幀大小: 480
# VAD 概率: 0.8221352696418762, 降噪後的幀大小: 480
# VAD 概率: 0.4926823675632477, 降噪後的幀大小: 480
# VAD 概率: 0.3372228145599365, 降噪後的幀大小: 480
# VAD 概率: 0.24505600333213806, 降噪後的幀大小: 480
# VAD 概率: 0.13980582356452942, 降噪後的幀大小: 480
# VAD 概率: 0.13105526566505432, 降噪後的幀大小: 480
# VAD 概率: 0.04015910625457764, 降噪後的幀大小: 480
# VAD 概率: 0.03040662407875061, 降噪後的幀大小: 480
# VAD 概率: 0.02539891004562378, 降噪後的幀大小: 480
# VAD 概率: 0.020489662885665894, 降噪後的幀大小: 480
# VAD 概率: 0.016057580709457397, 降噪後的幀大小: 480
# VAD 概率: 0.015279382467269897, 降噪後的幀大小: 480
# VAD 概率: 0.02086395025253296, 降噪後的幀大小: 480
# VAD 概率: 0.02913758158683777, 降噪後的幀大小: 480
# VAD 概率: 0.07214033603668213, 降噪後的幀大小: 480
# VAD 概率: 0.08222571015357971, 降噪後的幀大小: 480
# VAD 概率: 0.06413507461547852, 降噪後的幀大小: 480
# VAD 概率: 0.3570193350315094, 降噪後的幀大小: 480
# VAD 概率: 0.72834312915802, 降噪後的幀大小: 480
# VAD 概率: 0.927443265914917, 降噪後的幀大小: 480
# VAD 概率: 0.9694385528564453, 降噪後的幀大小: 480
# VAD 概率: 0.9786282777786255, 降噪後的幀大小: 480
# VAD 概率: 0.985938310623169, 降噪後的幀大小: 480
# VAD 概率: 0.9923591613769531, 降噪後的幀大小: 480
# VAD 概率: 0.9959020018577576, 降噪後的幀大小: 480
# VAD 概率: 0.9954918622970581, 降噪後的幀大小: 480
# VAD 概率: 0.9957532286643982, 降噪後的幀大小: 480
# VAD 概率: 0.9959947466850281, 降噪後的幀大小: 480
# VAD 概率: 0.997339129447937, 降噪後的幀大小: 480
# VAD 概率: 0.9981125593185425, 降噪後的幀大小: 480
# VAD 概率: 0.9976867437362671, 降噪後的幀大小: 480
# VAD 概率: 0.996862530708313, 降噪後的幀大小: 480
# VAD 概率: 0.997410774230957, 降噪後的幀大小: 480
# VAD 概率: 0.997586727142334, 降噪後的幀大小: 480
# VAD 概率: 0.9964507818222046, 降噪後的幀大小: 480
# VAD 概率: 0.9884871244430542, 降噪後的幀大小: 480
# VAD 概率: 0.9612771272659302, 降噪後的幀大小: 480
# VAD 概率: 0.9286400675773621, 降噪後的幀大小: 480
# VAD 概率: 0.7934355735778809, 降噪後的幀大小: 480
# VAD 概率: 0.5964857339859009, 降噪後的幀大小: 480
# VAD 概率: 0.3912585377693176, 降噪後的幀大小: 480
# VAD 概率: 0.7978271245956421, 降噪後的幀大小: 480
# VAD 概率: 0.8260906338691711, 降噪後的幀大小: 480
# VAD 概率: 0.5768139958381653, 降噪後的幀大小: 480
# VAD 概率: 0.5228284597396851, 降噪後的幀大小: 480
# VAD 概率: 0.8741970062255859, 降噪後的幀大小: 480
# VAD 概率: 0.9774254560470581, 降噪後的幀大小: 480
# VAD 概率: 0.9789150357246399, 降噪後的幀大小: 480
# VAD 概率: 0.9760701656341553, 降噪後的幀大小: 480
# VAD 概率: 0.9811503887176514, 降噪後的幀大小: 480
# VAD 概率: 0.9674659967422485, 降噪後的幀大小: 480
# VAD 概率: 0.9592344164848328, 降噪後的幀大小: 480
# VAD 概率: 0.9791771769523621, 降噪後的幀大小: 480
# VAD 概率: 0.9633928537368774, 降噪後的幀大小: 480
# VAD 概率: 0.9715190529823303, 降噪後的幀大小: 480
# VAD 概率: 0.9789263010025024, 降噪後的幀大小: 480
# VAD 概率: 0.9662582278251648, 降噪後的幀大小: 480
# VAD 概率: 0.8726231455802917, 降噪後的幀大小: 480
# VAD 概率: 0.7999875545501709, 降噪後的幀大小: 480
# VAD 概率: 0.7640049457550049, 降噪後的幀大小: 480
# VAD 概率: 0.7553433179855347, 降噪後的幀大小: 480
# VAD 概率: 0.8086491823196411, 降噪後的幀大小: 480
# VAD 概率: 0.8798432946205139, 降噪後的幀大小: 480
# VAD 概率: 0.9093133807182312, 降噪後的幀大小: 480
# VAD 概率: 0.9284422993659973, 降噪後的幀大小: 480
# VAD 概率: 0.9190203547477722, 降噪後的幀大小: 480
# VAD 概率: 0.8934680819511414, 降噪後的幀大小: 480
# VAD 概率: 0.9466589689254761, 降噪後的幀大小: 480
# VAD 概率: 0.9389313459396362, 降噪後的幀大小: 480
# VAD 概率: 0.9275439381599426, 降噪後的幀大小: 480
# VAD 概率: 0.8977581262588501, 降噪後的幀大小: 480
# VAD 概率: 0.8587056994438171, 降噪後的幀大小: 480
# VAD 概率: 0.8295037150382996, 降噪後的幀大小: 480
# VAD 概率: 0.8956653475761414, 降噪後的幀大小: 480
# VAD 概率: 0.9881948232650757, 降噪後的幀大小: 480
# VAD 概率: 0.995651364326477, 降噪後的幀大小: 480
# VAD 概率: 0.995547354221344, 降噪後的幀大小: 480
# VAD 概率: 0.9984325170516968, 降噪後的幀大小: 480
# VAD 概率: 0.9993499517440796, 降噪後的幀大小: 480
# VAD 概率: 0.9995714426040649, 降噪後的幀大小: 480
# VAD 概率: 0.9998018145561218, 降噪後的幀大小: 480
# VAD 概率: 0.9998421669006348, 降噪後的幀大小: 480
# VAD 概率: 0.9998677968978882, 降噪後的幀大小: 480
# VAD 概率: 0.9998723864555359, 降噪後的幀大小: 480
# VAD 概率: 0.9996595978736877, 降噪後的幀大小: 480
# VAD 概率: 0.9971461296081543, 降噪後的幀大小: 480
# VAD 概率: 0.9980494976043701, 降噪後的幀大小: 480
# VAD 概率: 0.9980703592300415, 降噪後的幀大小: 480
# VAD 概率: 0.9985360503196716, 降噪後的幀大小: 480
# VAD 概率: 0.998485803604126, 降噪後的幀大小: 480
# VAD 概率: 0.9993175268173218, 降噪後的幀大小: 480
# VAD 概率: 0.9992669820785522, 降噪後的幀大小: 480
# VAD 概率: 0.999053955078125, 降噪後的幀大小: 480
# VAD 概率: 0.9989227056503296, 降噪後的幀大小: 480
# VAD 概率: 0.998037576675415, 降噪後的幀大小: 480
# VAD 概率: 0.9975885152816772, 降噪後的幀大小: 480
# VAD 概率: 0.9973520040512085, 降噪後的幀大小: 480
# VAD 概率: 0.9949040412902832, 降噪後的幀大小: 480
# VAD 概率: 0.9927223920822144, 降噪後的幀大小: 480
# VAD 概率: 0.9975468516349792, 降噪後的幀大小: 480
# VAD 概率: 0.9996336698532104, 降噪後的幀大小: 480
# VAD 概率: 0.9998608827590942, 降噪後的幀大小: 480
# VAD 概率: 0.9999241828918457, 降噪後的幀大小: 480
# VAD 概率: 0.9999604821205139, 降噪後的幀大小: 480
# VAD 概率: 0.9999368190765381, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 0.9999790191650391, 降噪後的幀大小: 480
# VAD 概率: 0.9999450445175171, 降噪後的幀大小: 480
# VAD 概率: 0.9997780323028564, 降噪後的幀大小: 480
# VAD 概率: 0.9996672868728638, 降噪後的幀大小: 480
# VAD 概率: 0.9996821880340576, 降噪後的幀大小: 480
# VAD 概率: 0.9992635250091553, 降噪後的幀大小: 480
# VAD 概率: 0.9992950558662415, 降噪後的幀大小: 480
# VAD 概率: 0.9947962760925293, 降噪後的幀大小: 480
# VAD 概率: 0.9886289834976196, 降噪後的幀大小: 480
# VAD 概率: 0.9895021319389343, 降噪後的幀大小: 480
# VAD 概率: 0.9728018045425415, 降噪後的幀大小: 480
# VAD 概率: 0.9821285009384155, 降噪後的幀大小: 480
# VAD 概率: 0.9553661346435547, 降噪後的幀大小: 480
# VAD 概率: 0.8424481749534607, 降噪後的幀大小: 480
# VAD 概率: 0.7048205137252808, 降噪後的幀大小: 480
# VAD 概率: 0.47448715567588806, 降噪後的幀大小: 480
# VAD 概率: 0.41147392988204956, 降噪後的幀大小: 480
# VAD 概率: 0.5891428589820862, 降噪後的幀大小: 480
# VAD 概率: 0.8684852719306946, 降噪後的幀大小: 480
# VAD 概率: 0.8108938932418823, 降噪後的幀大小: 480
# VAD 概率: 0.5454242825508118, 降噪後的幀大小: 480
# VAD 概率: 0.26973775029182434, 降噪後的幀大小: 480
# VAD 概率: 0.5349316000938416, 降噪後的幀大小: 480
# VAD 概率: 0.7175663113594055, 降噪後的幀大小: 480
# VAD 概率: 0.7218865156173706, 降噪後的幀大小: 480
# VAD 概率: 0.6265127658843994, 降噪後的幀大小: 480
# VAD 概率: 0.4971133768558502, 降噪後的幀大小: 480
# VAD 概率: 0.4183884263038635, 降噪後的幀大小: 480
# VAD 概率: 0.7253006100654602, 降噪後的幀大小: 480
# VAD 概率: 0.8744943141937256, 降噪後的幀大小: 480
# VAD 概率: 0.7066166996955872, 降噪後的幀大小: 480
# VAD 概率: 0.8993679881095886, 降噪後的幀大小: 480
# VAD 概率: 0.8988286256790161, 降噪後的幀大小: 480
# VAD 概率: 0.8571276664733887, 降噪後的幀大小: 480
# VAD 概率: 0.8199417591094971, 降噪後的幀大小: 480
# VAD 概率: 0.9066637754440308, 降噪後的幀大小: 480
# VAD 概率: 0.8748924732208252, 降噪後的幀大小: 480
# VAD 概率: 0.8608789443969727, 降噪後的幀大小: 480
# VAD 概率: 0.9357419013977051, 降噪後的幀大小: 480
# VAD 概率: 0.8110461235046387, 降噪後的幀大小: 480
# VAD 概率: 0.5253887176513672, 降噪後的幀大小: 480
# VAD 概率: 0.2014756202697754, 降噪後的幀大小: 480
# VAD 概率: 0.10609573125839233, 降噪後的幀大小: 480
# VAD 概率: 0.05925670266151428, 降噪後的幀大小: 480
# VAD 概率: 0.0489981472492218, 降噪後的幀大小: 480
# VAD 概率: 0.02959120273590088, 降噪後的幀大小: 480
# VAD 概率: 0.01569262146949768, 降噪後的幀大小: 480
# VAD 概率: 0.014267802238464355, 降噪後的幀大小: 480
# VAD 概率: 0.010558784008026123, 降噪後的幀大小: 480
# VAD 概率: 0.007219910621643066, 降噪後的幀大小: 480
# VAD 概率: 0.006809055805206299, 降噪後的幀大小: 480
# VAD 概率: 0.008205115795135498, 降噪後的幀大小: 480
# VAD 概率: 0.006871998310089111, 降噪後的幀大小: 480
# VAD 概率: 0.010761231184005737, 降噪後的幀大小: 480
# VAD 概率: 0.020992189645767212, 降噪後的幀大小: 480
# VAD 概率: 0.048271507024765015, 降噪後的幀大小: 480
# VAD 概率: 0.027164340019226074, 降噪後的幀大小: 480
# VAD 概率: 0.05267110466957092, 降噪後的幀大小: 480
# VAD 概率: 0.031821638345718384, 降噪後的幀大小: 480
# VAD 概率: 0.21314257383346558, 降噪後的幀大小: 480
# VAD 概率: 0.46294572949409485, 降噪後的幀大小: 480
# VAD 概率: 0.4151337444782257, 降噪後的幀大小: 480
# VAD 概率: 0.5223113894462585, 降噪後的幀大小: 480
# VAD 概率: 0.3824491500854492, 降噪後的幀大小: 480
# VAD 概率: 0.22596034407615662, 降噪後的幀大小: 480
# VAD 概率: 0.130754292011261, 降噪後的幀大小: 480
# VAD 概率: 0.07693752646446228, 降噪後的幀大小: 480
# VAD 概率: 0.15576139092445374, 降噪後的幀大小: 480
# VAD 概率: 0.04670590162277222, 降噪後的幀大小: 480
# VAD 概率: 0.022112518548965454, 降噪後的幀大小: 480
# VAD 概率: 0.018907934427261353, 降噪後的幀大小: 480
# VAD 概率: 0.016279518604278564, 降噪後的幀大小: 480
# VAD 概率: 0.012205183506011963, 降噪後的幀大小: 480
# VAD 概率: 0.010645359754562378, 降噪後的幀大小: 480
# VAD 概率: 0.005932539701461792, 降噪後的幀大小: 480
# VAD 概率: 0.00705331563949585, 降噪後的幀大小: 480
# VAD 概率: 0.018268883228302002, 降噪後的幀大小: 480
# VAD 概率: 0.06958004832267761, 降噪後的幀大小: 480
# VAD 概率: 0.4805212616920471, 降噪後的幀大小: 480
# VAD 概率: 0.6420667171478271, 降噪後的幀大小: 480
# VAD 概率: 0.299506276845932, 降噪後的幀大小: 480
# VAD 概率: 0.19553053379058838, 降噪後的幀大小: 480
# VAD 概率: 0.18025559186935425, 降噪後的幀大小: 480
# VAD 概率: 0.04416099190711975, 降噪後的幀大小: 480
# VAD 概率: 0.02312469482421875, 降噪後的幀大小: 480
# VAD 概率: 0.013328522443771362, 降噪後的幀大小: 480
# VAD 概率: 0.008952111005783081, 降噪後的幀大小: 480
# VAD 概率: 0.006918817758560181, 降噪後的幀大小: 480
# VAD 概率: 0.008124619722366333, 降噪後的幀大小: 480
# VAD 概率: 0.007144182920455933, 降噪後的幀大小: 480
# VAD 概率: 0.006567507982254028, 降噪後的幀大小: 480
# VAD 概率: 0.005729615688323975, 降噪後的幀大小: 480
# VAD 概率: 0.005699843168258667, 降噪後的幀大小: 480
# VAD 概率: 0.006537258625030518, 降噪後的幀大小: 480
# VAD 概率: 0.010580331087112427, 降噪後的幀大小: 480
# VAD 概率: 0.008675724267959595, 降噪後的幀大小: 480
# VAD 概率: 0.007788509130477905, 降噪後的幀大小: 480
# VAD 概率: 0.006694972515106201, 降噪後的幀大小: 480
# VAD 概率: 0.0058554112911224365, 降噪後的幀大小: 480
# VAD 概率: 0.005273491144180298, 降噪後的幀大小: 480
# VAD 概率: 0.009445041418075562, 降噪後的幀大小: 480
# VAD 概率: 0.015666186809539795, 降噪後的幀大小: 480
# VAD 概率: 0.019873052835464478, 降噪後的幀大小: 480
# VAD 概率: 0.00643804669380188, 降噪後的幀大小: 480
# VAD 概率: 0.008069813251495361, 降噪後的幀大小: 480
# VAD 概率: 0.011600881814956665, 降噪後的幀大小: 480
# VAD 概率: 0.014101088047027588, 降噪後的幀大小: 480
# VAD 概率: 0.02099478244781494, 降噪後的幀大小: 480
# VAD 概率: 0.0525590181350708, 降噪後的幀大小: 480
# VAD 概率: 0.04041624069213867, 降噪後的幀大小: 480
# VAD 概率: 0.9038926362991333, 降噪後的幀大小: 480
# VAD 概率: 0.9990888237953186, 降噪後的幀大小: 480
# VAD 概率: 0.9998825788497925, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 0.9999984502792358, 降噪後的幀大小: 480
# VAD 概率: 0.9999902248382568, 降噪後的幀大小: 480
# VAD 概率: 0.9999898076057434, 降噪後的幀大小: 480
# VAD 概率: 0.9999685287475586, 降噪後的幀大小: 480
# VAD 概率: 0.9999265670776367, 降噪後的幀大小: 480
# VAD 概率: 0.9997425675392151, 降噪後的幀大小: 480
# VAD 概率: 0.9987616539001465, 降噪後的幀大小: 480
# VAD 概率: 0.9821988344192505, 降噪後的幀大小: 480
# VAD 概率: 0.9703874588012695, 降噪後的幀大小: 480
# VAD 概率: 0.9839328527450562, 降噪後的幀大小: 480
# VAD 概率: 0.9732896089553833, 降噪後的幀大小: 480
# VAD 概率: 0.9987766742706299, 降噪後的幀大小: 480
# VAD 概率: 0.9998933672904968, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 0.999983549118042, 降噪後的幀大小: 480
# VAD 概率: 0.9998462200164795, 降噪後的幀大小: 480
# VAD 概率: 0.9985886216163635, 降噪後的幀大小: 480
# VAD 概率: 0.9878720045089722, 降噪後的幀大小: 480
# VAD 概率: 0.9373319149017334, 降噪後的幀大小: 480
# VAD 概率: 0.987326443195343, 降噪後的幀大小: 480
# VAD 概率: 0.9905320405960083, 降噪後的幀大小: 480
# VAD 概率: 0.9952096343040466, 降噪後的幀大小: 480
# VAD 概率: 0.9988158941268921, 降噪後的幀大小: 480
# VAD 概率: 0.9998518228530884, 降噪後的幀大小: 480
# VAD 概率: 0.9999680519104004, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 0.9999566078186035, 降噪後的幀大小: 480
# VAD 概率: 0.9999412298202515, 降噪後的幀大小: 480
# VAD 概率: 0.9999249577522278, 降噪後的幀大小: 480
# VAD 概率: 0.9998936653137207, 降噪後的幀大小: 480
# VAD 概率: 0.999860405921936, 降噪後的幀大小: 480
# VAD 概率: 0.9997726082801819, 降噪後的幀大小: 480
# VAD 概率: 0.9997544884681702, 降噪後的幀大小: 480
# VAD 概率: 0.9994001984596252, 降噪後的幀大小: 480
# VAD 概率: 0.999586820602417, 降噪後的幀大小: 480
# VAD 概率: 0.9995406866073608, 降噪後的幀大小: 480
# VAD 概率: 0.9989547729492188, 降噪後的幀大小: 480
# VAD 概率: 0.9911613464355469, 降噪後的幀大小: 480
# VAD 概率: 0.9805923700332642, 降噪後的幀大小: 480
# VAD 概率: 0.988182783126831, 降噪後的幀大小: 480
# VAD 概率: 0.9963762164115906, 降噪後的幀大小: 480
# VAD 概率: 0.9991412162780762, 降噪後的幀大小: 480
# VAD 概率: 0.9997538924217224, 降噪後的幀大小: 480
# VAD 概率: 0.9998710751533508, 降噪後的幀大小: 480
# VAD 概率: 0.9998940229415894, 降噪後的幀大小: 480
# VAD 概率: 0.999884307384491, 降噪後的幀大小: 480
# VAD 概率: 0.9999338388442993, 降噪後的幀大小: 480
# VAD 概率: 0.9999427199363708, 降噪後的幀大小: 480
# VAD 概率: 0.9999772310256958, 降噪後的幀大小: 480
# VAD 概率: 0.9999991059303284, 降噪後的幀大小: 480
# VAD 概率: 0.9999935626983643, 降噪後的幀大小: 480
# VAD 概率: 0.999980092048645, 降噪後的幀大小: 480
# VAD 概率: 0.9999179840087891, 降噪後的幀大小: 480
# VAD 概率: 0.9998652935028076, 降噪後的幀大小: 480
# VAD 概率: 0.999700665473938, 降噪後的幀大小: 480
# VAD 概率: 0.9980939626693726, 降噪後的幀大小: 480
# VAD 概率: 0.9925864338874817, 降噪後的幀大小: 480
# VAD 概率: 0.9823542833328247, 降噪後的幀大小: 480
# VAD 概率: 0.9996233582496643, 降噪後的幀大小: 480
# VAD 概率: 0.9998990297317505, 降噪後的幀大小: 480
# VAD 概率: 0.9999310970306396, 降噪後的幀大小: 480
# VAD 概率: 0.9999324083328247, 降噪後的幀大小: 480
# VAD 概率: 0.9998533725738525, 降噪後的幀大小: 480
# VAD 概率: 0.9998883008956909, 降噪後的幀大小: 480
# VAD 概率: 0.9999079704284668, 降噪後的幀大小: 480
# VAD 概率: 0.9998399019241333, 降噪後的幀大小: 480
# VAD 概率: 0.9984709024429321, 降噪後的幀大小: 480
# VAD 概率: 0.9943152666091919, 降噪後的幀大小: 480
# VAD 概率: 0.9830887913703918, 降噪後的幀大小: 480
# VAD 概率: 0.9554663896560669, 降噪後的幀大小: 480
# VAD 概率: 0.9548690319061279, 降噪後的幀大小: 480
# VAD 概率: 0.9867111444473267, 降噪後的幀大小: 480
# VAD 概率: 0.9892444014549255, 降噪後的幀大小: 480
# VAD 概率: 0.994182288646698, 降噪後的幀大小: 480
# VAD 概率: 0.9976224899291992, 降噪後的幀大小: 480
# VAD 概率: 0.9984339475631714, 降噪後的幀大小: 480
# VAD 概率: 0.9982218742370605, 降噪後的幀大小: 480
# VAD 概率: 0.9982394576072693, 降噪後的幀大小: 480
# VAD 概率: 0.9971789121627808, 降噪後的幀大小: 480
# VAD 概率: 0.9978143572807312, 降噪後的幀大小: 480
# VAD 概率: 0.9987695813179016, 降噪後的幀大小: 480
# VAD 概率: 0.9991511106491089, 降噪後的幀大小: 480
# VAD 概率: 0.9988952875137329, 降噪後的幀大小: 480
# VAD 概率: 0.9987055063247681, 降噪後的幀大小: 480
# VAD 概率: 0.9982987642288208, 降噪後的幀大小: 480
# VAD 概率: 0.9978054761886597, 降噪後的幀大小: 480
# VAD 概率: 0.9983072280883789, 降噪後的幀大小: 480
# VAD 概率: 0.9993538856506348, 降噪後的幀大小: 480
# VAD 概率: 0.9994066953659058, 降噪後的幀大小: 480
# VAD 概率: 0.9985538721084595, 降噪後的幀大小: 480
# VAD 概率: 0.993502140045166, 降噪後的幀大小: 480
# VAD 概率: 0.9863287210464478, 降噪後的幀大小: 480
# VAD 概率: 0.9896865487098694, 降噪後的幀大小: 480
# VAD 概率: 0.9918222427368164, 降噪後的幀大小: 480
# VAD 概率: 0.9939998388290405, 降噪後的幀大小: 480
# VAD 概率: 0.9935039281845093, 降噪後的幀大小: 480
# VAD 概率: 0.9944373965263367, 降噪後的幀大小: 480
# VAD 概率: 0.9956133365631104, 降噪後的幀大小: 480
# VAD 概率: 0.9958379864692688, 降噪後的幀大小: 480
# VAD 概率: 0.9956167936325073, 降噪後的幀大小: 480
# VAD 概率: 0.9935494661331177, 降噪後的幀大小: 480
# VAD 概率: 0.980828046798706, 降噪後的幀大小: 480
# VAD 概率: 0.931995689868927, 降噪後的幀大小: 480
# VAD 概率: 0.8898329734802246, 降噪後的幀大小: 480
# VAD 概率: 0.9802488088607788, 降噪後的幀大小: 480
# VAD 概率: 0.9944980144500732, 降噪後的幀大小: 480
# VAD 概率: 0.997156023979187, 降噪後的幀大小: 480
# VAD 概率: 0.9981750249862671, 降噪後的幀大小: 480
# VAD 概率: 0.9990122318267822, 降噪後的幀大小: 480
# VAD 概率: 0.998396635055542, 降噪後的幀大小: 480
# VAD 概率: 0.993165910243988, 降噪後的幀大小: 480
# VAD 概率: 0.969883918762207, 降噪後的幀大小: 480
# VAD 概率: 0.9799838662147522, 降噪後的幀大小: 480
# VAD 概率: 0.984740138053894, 降噪後的幀大小: 480
# VAD 概率: 0.9632042050361633, 降噪後的幀大小: 480
# VAD 概率: 0.971672534942627, 降噪後的幀大小: 480
# VAD 概率: 0.9898866415023804, 降噪後的幀大小: 480
# VAD 概率: 0.9973851442337036, 降噪後的幀大小: 480
# VAD 概率: 0.9988181591033936, 降噪後的幀大小: 480
# VAD 概率: 0.999423623085022, 降噪後的幀大小: 480
# VAD 概率: 0.9995595216751099, 降噪後的幀大小: 480
# VAD 概率: 0.9997145533561707, 降噪後的幀大小: 480
# VAD 概率: 0.9997986555099487, 降噪後的幀大小: 480
# VAD 概率: 0.9998568296432495, 降噪後的幀大小: 480
# VAD 概率: 0.99985671043396, 降噪後的幀大小: 480
# VAD 概率: 0.999849259853363, 降噪後的幀大小: 480
# VAD 概率: 0.9998680949211121, 降噪後的幀大小: 480
# VAD 概率: 0.9998761415481567, 降噪後的幀大小: 480
# VAD 概率: 0.9998262524604797, 降噪後的幀大小: 480
# VAD 概率: 0.999845564365387, 降噪後的幀大小: 480
# VAD 概率: 0.9998530745506287, 降噪後的幀大小: 480
# VAD 概率: 0.9998036026954651, 降噪後的幀大小: 480
# VAD 概率: 0.9997976422309875, 降噪後的幀大小: 480
# VAD 概率: 0.9997793436050415, 降噪後的幀大小: 480
# VAD 概率: 0.9997325539588928, 降噪後的幀大小: 480
# VAD 概率: 0.9998032450675964, 降噪後的幀大小: 480
# VAD 概率: 0.999794602394104, 降噪後的幀大小: 480
# VAD 概率: 0.9998319745063782, 降噪後的幀大小: 480
# VAD 概率: 0.9998533725738525, 降噪後的幀大小: 480
# VAD 概率: 0.9998195171356201, 降噪後的幀大小: 480
# VAD 概率: 0.9998205304145813, 降噪後的幀大小: 480
# VAD 概率: 0.9998561143875122, 降噪後的幀大小: 480
# VAD 概率: 0.9998563528060913, 降噪後的幀大小: 480
# VAD 概率: 0.9998345971107483, 降噪後的幀大小: 480
# VAD 概率: 0.999817967414856, 降噪後的幀大小: 480
# VAD 概率: 0.9998281002044678, 降噪後的幀大小: 480
# VAD 概率: 0.9997782707214355, 降噪後的幀大小: 480
# VAD 概率: 0.999798059463501, 降噪後的幀大小: 480
# VAD 概率: 0.9998124837875366, 降噪後的幀大小: 480
# VAD 概率: 0.9998347759246826, 降噪後的幀大小: 480
# VAD 概率: 0.9998003244400024, 降噪後的幀大小: 480
# VAD 概率: 0.9997470378875732, 降噪後的幀大小: 480
# VAD 概率: 0.9998151659965515, 降噪後的幀大小: 480
# VAD 概率: 0.9998440742492676, 降噪後的幀大小: 480
# VAD 概率: 0.9998432993888855, 降噪後的幀大小: 480
# VAD 概率: 0.9997667670249939, 降噪後的幀大小: 480
# VAD 概率: 0.9997838735580444, 降噪後的幀大小: 480
# VAD 概率: 0.9995602369308472, 降噪後的幀大小: 480
# VAD 概率: 0.9982773065567017, 降噪後的幀大小: 480
# VAD 概率: 0.9960490465164185, 降噪後的幀大小: 480
# VAD 概率: 0.9959970116615295, 降噪後的幀大小: 480
# VAD 概率: 0.9969443082809448, 降噪後的幀大小: 480
# VAD 概率: 0.9852516651153564, 降噪後的幀大小: 480
# VAD 概率: 0.96955406665802, 降噪後的幀大小: 480
# VAD 概率: 0.9588499069213867, 降噪後的幀大小: 480
# VAD 概率: 0.9526127576828003, 降噪後的幀大小: 480
# VAD 概率: 0.9060900211334229, 降噪後的幀大小: 480
# VAD 概率: 0.8282256126403809, 降噪後的幀大小: 480
# VAD 概率: 0.9227136373519897, 降噪後的幀大小: 480
# VAD 概率: 0.9789556264877319, 降噪後的幀大小: 480
# VAD 概率: 0.9899086356163025, 降噪後的幀大小: 480
# VAD 概率: 0.996918797492981, 降噪後的幀大小: 480
# VAD 概率: 0.9967476725578308, 降噪後的幀大小: 480
# VAD 概率: 0.9972232580184937, 降噪後的幀大小: 480
# VAD 概率: 0.9984482526779175, 降噪後的幀大小: 480
# VAD 概率: 0.9988700151443481, 降噪後的幀大小: 480
# VAD 概率: 0.9991376399993896, 降噪後的幀大小: 480
# VAD 概率: 0.9993907809257507, 降噪後的幀大小: 480
# VAD 概率: 0.9996515512466431, 降噪後的幀大小: 480
# VAD 概率: 0.9996612668037415, 降噪後的幀大小: 480
# VAD 概率: 0.9997597932815552, 降噪後的幀大小: 480
# VAD 概率: 0.9996209740638733, 降噪後的幀大小: 480
# VAD 概率: 0.9995676875114441, 降噪後的幀大小: 480
# VAD 概率: 0.9996047616004944, 降噪後的幀大小: 480
# VAD 概率: 0.9994975328445435, 降噪後的幀大小: 480
# VAD 概率: 0.9994237422943115, 降噪後的幀大小: 480
# VAD 概率: 0.9993494153022766, 降噪後的幀大小: 480
# VAD 概率: 0.9995615482330322, 降噪後的幀大小: 480
# VAD 概率: 0.9996981024742126, 降噪後的幀大小: 480
# VAD 概率: 0.9998279809951782, 降噪後的幀大小: 480
# VAD 概率: 0.9998470544815063, 降噪後的幀大小: 480
# VAD 概率: 0.9998428821563721, 降噪後的幀大小: 480
# VAD 概率: 0.9997285604476929, 降噪後的幀大小: 480
# VAD 概率: 0.9997655749320984, 降噪後的幀大小: 480
# VAD 概率: 0.9998281002044678, 降噪後的幀大小: 480
# VAD 概率: 0.9998798370361328, 降噪後的幀大小: 480
# VAD 概率: 0.9998944997787476, 降噪後的幀大小: 480
# VAD 概率: 0.9999369978904724, 降噪後的幀大小: 480
# VAD 概率: 0.999932050704956, 降噪後的幀大小: 480
# VAD 概率: 0.9999303817749023, 降噪後的幀大小: 480
# VAD 概率: 0.9999619722366333, 降噪後的幀大小: 480
# VAD 概率: 0.9999732971191406, 降噪後的幀大小: 480
# VAD 概率: 0.9999303817749023, 降噪後的幀大小: 480
# VAD 概率: 0.9998987913131714, 降噪後的幀大小: 480
# VAD 概率: 0.9997850656509399, 降噪後的幀大小: 480
# VAD 概率: 0.9995554685592651, 降噪後的幀大小: 480
# VAD 概率: 0.9982850551605225, 降噪後的幀大小: 480
# VAD 概率: 0.9988479614257812, 降噪後的幀大小: 480
# VAD 概率: 0.9968428611755371, 降噪後的幀大小: 480
# VAD 概率: 0.9884516000747681, 降噪後的幀大小: 480
# VAD 概率: 0.9878295063972473, 降噪後的幀大小: 480
# VAD 概率: 0.96225506067276, 降噪後的幀大小: 480
# VAD 概率: 0.9589067101478577, 降噪後的幀大小: 480
# VAD 概率: 0.9606902003288269, 降噪後的幀大小: 480
# VAD 概率: 0.9530829191207886, 降噪後的幀大小: 480
# VAD 概率: 0.9642388820648193, 降噪後的幀大小: 480
# VAD 概率: 0.9260943531990051, 降噪後的幀大小: 480
# VAD 概率: 0.9037836790084839, 降噪後的幀大小: 480
# VAD 概率: 0.7767288088798523, 降噪後的幀大小: 480
# VAD 概率: 0.562645435333252, 降噪後的幀大小: 480
# VAD 概率: 0.2722935974597931, 降噪後的幀大小: 480
# VAD 概率: 0.11661261320114136, 降噪後的幀大小: 480
# VAD 概率: 0.08288270235061646, 降噪後的幀大小: 480
# VAD 概率: 0.245100200176239, 降噪後的幀大小: 480
# VAD 概率: 0.3766188323497772, 降噪後的幀大小: 480
# VAD 概率: 0.3877599239349365, 降噪後的幀大小: 480
# VAD 概率: 0.16176393628120422, 降噪後的幀大小: 480
# VAD 概率: 0.6254146099090576, 降噪後的幀大小: 480
# VAD 概率: 0.6266206502914429, 降噪後的幀大小: 480
# VAD 概率: 0.5745478868484497, 降噪後的幀大小: 480
# VAD 概率: 0.7360074520111084, 降噪後的幀大小: 480
# VAD 概率: 0.19088846445083618, 降噪後的幀大小: 480
# VAD 概率: 0.07728001475334167, 降噪後的幀大小: 480
# VAD 概率: 0.04296964406967163, 降噪後的幀大小: 480
# VAD 概率: 0.027074545621871948, 降噪後的幀大小: 480
# VAD 概率: 0.023493826389312744, 降噪後的幀大小: 480
# VAD 概率: 0.011398375034332275, 降噪後的幀大小: 480
# VAD 概率: 0.009455859661102295, 降噪後的幀大小: 480
# VAD 概率: 0.011667370796203613, 降噪後的幀大小: 480
# VAD 概率: 0.0037927329540252686, 降噪後的幀大小: 480
# VAD 概率: 0.0033636093139648438, 降噪後的幀大小: 480
# VAD 概率: 0.004017293453216553, 降噪後的幀大小: 480
# VAD 概率: 0.004426091909408569, 降噪後的幀大小: 480
# VAD 概率: 0.00567743182182312, 降噪後的幀大小: 480
# VAD 概率: 0.005143612623214722, 降噪後的幀大小: 480
# VAD 概率: 0.007097214460372925, 降噪後的幀大小: 480
# VAD 概率: 0.02147853374481201, 降噪後的幀大小: 480
# VAD 概率: 0.14392760396003723, 降噪後的幀大小: 480
# VAD 概率: 0.2019260823726654, 降噪後的幀大小: 480
# VAD 概率: 0.17388305068016052, 降噪後的幀大小: 480
# VAD 概率: 0.03251120448112488, 降噪後的幀大小: 480
# VAD 概率: 0.01051795482635498, 降噪後的幀大小: 480
# VAD 概率: 0.0064095258712768555, 降噪後的幀大小: 480
# VAD 概率: 0.00549665093421936, 降噪後的幀大小: 480
# VAD 概率: 0.004917889833450317, 降噪後的幀大小: 480
# VAD 概率: 0.003199964761734009, 降噪後的幀大小: 480
# VAD 概率: 0.007151007652282715, 降噪後的幀大小: 480
# VAD 概率: 0.005535751581192017, 降噪後的幀大小: 480
# VAD 概率: 0.0033386945724487305, 降噪後的幀大小: 480
# VAD 概率: 0.003367096185684204, 降噪後的幀大小: 480
# VAD 概率: 0.003436952829360962, 降噪後的幀大小: 480
# VAD 概率: 0.0033180415630340576, 降噪後的幀大小: 480
# VAD 概率: 0.0031090080738067627, 降噪後的幀大小: 480
# VAD 概率: 0.00241735577583313, 降噪後的幀大小: 480
# VAD 概率: 0.0020147860050201416, 降噪後的幀大小: 480
# VAD 概率: 0.0015589892864227295, 降噪後的幀大小: 480
# VAD 概率: 0.0014523565769195557, 降噪後的幀大小: 480
# VAD 概率: 0.00144919753074646, 降噪後的幀大小: 480
# VAD 概率: 0.0014403760433197021, 降噪後的幀大小: 480
# VAD 概率: 0.0008552372455596924, 降噪後的幀大小: 480
# VAD 概率: 0.0007999539375305176, 降噪後的幀大小: 480
# VAD 概率: 0.0011236071586608887, 降噪後的幀大小: 480
# VAD 概率: 0.0015956461429595947, 降噪後的幀大小: 480
# VAD 概率: 0.001539468765258789, 降噪後的幀大小: 480
# VAD 概率: 0.0025713443756103516, 降噪後的幀大小: 480
# VAD 概率: 0.014068841934204102, 降噪後的幀大小: 480
# VAD 概率: 0.03154042363166809, 降噪後的幀大小: 480
# VAD 概率: 0.007915019989013672, 降噪後的幀大小: 480
# VAD 概率: 0.004879206418991089, 降噪後的幀大小: 480
# VAD 概率: 0.4013764262199402, 降噪後的幀大小: 480
# VAD 概率: 0.9901895523071289, 降噪後的幀大小: 480
# VAD 概率: 0.9992548227310181, 降噪後的幀大小: 480
# VAD 概率: 0.9998750686645508, 降噪後的幀大小: 480
# VAD 概率: 0.9999459981918335, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 0.9999790787696838, 降噪後的幀大小: 480
# VAD 概率: 0.9999816417694092, 降噪後的幀大小: 480
# VAD 概率: 0.9999346733093262, 降噪後的幀大小: 480
# VAD 概率: 0.9999597072601318, 降噪後的幀大小: 480
# VAD 概率: 0.9999463558197021, 降噪後的幀大小: 480
# VAD 概率: 0.9998902678489685, 降噪後的幀大小: 480
# VAD 概率: 0.999828577041626, 降噪後的幀大小: 480
# VAD 概率: 0.9997628927230835, 降噪後的幀大小: 480
# VAD 概率: 0.9997998476028442, 降噪後的幀大小: 480
# VAD 概率: 0.9996942281723022, 降噪後的幀大小: 480
# VAD 概率: 0.9981880784034729, 降噪後的幀大小: 480
# VAD 概率: 0.995208740234375, 降噪後的幀大小: 480
# VAD 概率: 0.991692841053009, 降噪後的幀大小: 480
# VAD 概率: 0.9977855086326599, 降噪後的幀大小: 480
# VAD 概率: 0.9993531703948975, 降噪後的幀大小: 480
# VAD 概率: 0.9992063045501709, 降噪後的幀大小: 480
# VAD 概率: 0.9986016750335693, 降噪後的幀大小: 480
# VAD 概率: 0.9988969564437866, 降噪後的幀大小: 480
# VAD 概率: 0.9997618794441223, 降噪後的幀大小: 480
# VAD 概率: 0.9999845623970032, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 0.9999781847000122, 降噪後的幀大小: 480
# VAD 概率: 0.9998939037322998, 降噪後的幀大小: 480
# VAD 概率: 0.9997290372848511, 降噪後的幀大小: 480
# VAD 概率: 0.999248743057251, 降噪後的幀大小: 480
# VAD 概率: 0.9988034963607788, 降噪後的幀大小: 480
# VAD 概率: 0.9990065097808838, 降噪後的幀大小: 480
# VAD 概率: 0.9992924928665161, 降噪後的幀大小: 480
# VAD 概率: 0.9993947148323059, 降噪後的幀大小: 480
# VAD 概率: 0.999380350112915, 降噪後的幀大小: 480
# VAD 概率: 0.9985869526863098, 降噪後的幀大小: 480
# VAD 概率: 0.999026358127594, 降噪後的幀大小: 480
# VAD 概率: 0.9998589158058167, 降噪後的幀大小: 480
# VAD 概率: 0.9999885559082031, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 0.9999791383743286, 降噪後的幀大小: 480
# VAD 概率: 0.9998776912689209, 降噪後的幀大小: 480
# VAD 概率: 0.9998453855514526, 降噪後的幀大小: 480
# VAD 概率: 0.9997673630714417, 降噪後的幀大小: 480
# VAD 概率: 0.9988480806350708, 降噪後的幀大小: 480
# VAD 概率: 0.9973247051239014, 降噪後的幀大小: 480
# VAD 概率: 0.998816728591919, 降噪後的幀大小: 480
# VAD 概率: 0.9972051382064819, 降噪後的幀大小: 480
# VAD 概率: 0.9812954068183899, 降噪後的幀大小: 480
# VAD 概率: 0.979576826095581, 降噪後的幀大小: 480
# VAD 概率: 0.9894986152648926, 降噪後的幀大小: 480
# VAD 概率: 0.9948792457580566, 降噪後的幀大小: 480
# VAD 概率: 0.9888684749603271, 降噪後的幀大小: 480
# VAD 概率: 0.9791918992996216, 降噪後的幀大小: 480
# VAD 概率: 0.9985717535018921, 降噪後的幀大小: 480
# VAD 概率: 0.9995664358139038, 降噪後的幀大小: 480
# VAD 概率: 0.9997377395629883, 降噪後的幀大小: 480
# VAD 概率: 0.9997298717498779, 降噪後的幀大小: 480
# VAD 概率: 0.9997642636299133, 降噪後的幀大小: 480
# VAD 概率: 0.9997904300689697, 降噪後的幀大小: 480
# VAD 概率: 0.9997538328170776, 降噪後的幀大小: 480
# VAD 概率: 0.9996757507324219, 降噪後的幀大小: 480
# VAD 概率: 0.9996493458747864, 降噪後的幀大小: 480
# VAD 概率: 0.9996224641799927, 降噪後的幀大小: 480
# VAD 概率: 0.9994098544120789, 降噪後的幀大小: 480
# VAD 概率: 0.9989866018295288, 降噪後的幀大小: 480
# VAD 概率: 0.99852454662323, 降噪後的幀大小: 480
# VAD 概率: 0.9923639297485352, 降噪後的幀大小: 480
# VAD 概率: 0.9630640745162964, 降噪後的幀大小: 480
# VAD 概率: 0.8970918655395508, 降噪後的幀大小: 480
# VAD 概率: 0.6472073793411255, 降噪後的幀大小: 480
# VAD 概率: 0.41611403226852417, 降噪後的幀大小: 480
# VAD 概率: 0.4093242287635803, 降噪後的幀大小: 480
# VAD 概率: 0.8911225199699402, 降噪後的幀大小: 480
# VAD 概率: 0.9901041388511658, 降噪後的幀大小: 480
# VAD 概率: 0.9761590957641602, 降噪後的幀大小: 480
# VAD 概率: 0.9768689274787903, 降噪後的幀大小: 480
# VAD 概率: 0.994566798210144, 降噪後的幀大小: 480
# VAD 概率: 0.995497465133667, 降噪後的幀大小: 480
# VAD 概率: 0.9928611516952515, 降噪後的幀大小: 480
# VAD 概率: 0.980101466178894, 降噪後的幀大小: 480
# VAD 概率: 0.9854087233543396, 降噪後的幀大小: 480
# VAD 概率: 0.9863244295120239, 降噪後的幀大小: 480
# VAD 概率: 0.9945751428604126, 降噪後的幀大小: 480
# VAD 概率: 0.9918643236160278, 降噪後的幀大小: 480
# VAD 概率: 0.9920323491096497, 降噪後的幀大小: 480
# VAD 概率: 0.9897963404655457, 降噪後的幀大小: 480
# VAD 概率: 0.9839839339256287, 降噪後的幀大小: 480
# VAD 概率: 0.9629494547843933, 降噪後的幀大小: 480
# VAD 概率: 0.8969771862030029, 降噪後的幀大小: 480
# VAD 概率: 0.7491412162780762, 降噪後的幀大小: 480
# VAD 概率: 0.805834949016571, 降噪後的幀大小: 480
# VAD 概率: 0.5727496147155762, 降噪後的幀大小: 480
# VAD 概率: 0.2675379812717438, 降噪後的幀大小: 480
# VAD 概率: 0.37485501170158386, 降噪後的幀大小: 480
# VAD 概率: 0.21264591813087463, 降噪後的幀大小: 480
# VAD 概率: 0.23430871963500977, 降噪後的幀大小: 480
# VAD 概率: 0.45322588086128235, 降噪後的幀大小: 480
# VAD 概率: 0.6504499912261963, 降噪後的幀大小: 480
# VAD 概率: 0.9071521759033203, 降噪後的幀大小: 480
# VAD 概率: 0.8825667500495911, 降噪後的幀大小: 480
# VAD 概率: 0.905643880367279, 降噪後的幀大小: 480
# VAD 概率: 0.9771195650100708, 降噪後的幀大小: 480
# VAD 概率: 0.9659489393234253, 降噪後的幀大小: 480
# VAD 概率: 0.9536805152893066, 降噪後的幀大小: 480
# VAD 概率: 0.9158260822296143, 降噪後的幀大小: 480
# VAD 概率: 0.8438016176223755, 降噪後的幀大小: 480
# VAD 概率: 0.8328343629837036, 降噪後的幀大小: 480
# VAD 概率: 0.7647842168807983, 降噪後的幀大小: 480
# VAD 概率: 0.6866589188575745, 降噪後的幀大小: 480
# VAD 概率: 0.5379164814949036, 降噪後的幀大小: 480
# VAD 概率: 0.44228270649909973, 降噪後的幀大小: 480
# VAD 概率: 0.35172075033187866, 降噪後的幀大小: 480
# VAD 概率: 0.16909712553024292, 降噪後的幀大小: 480
# VAD 概率: 0.09833401441574097, 降噪後的幀大小: 480
# VAD 概率: 0.08177819848060608, 降噪後的幀大小: 480
# VAD 概率: 0.04635021090507507, 降噪後的幀大小: 480
# VAD 概率: 0.023044496774673462, 降噪後的幀大小: 480
# VAD 概率: 0.010287582874298096, 降噪後的幀大小: 480
# VAD 概率: 0.0067596435546875, 降噪後的幀大小: 480
# VAD 概率: 0.005501359701156616, 降噪後的幀大小: 480
# VAD 概率: 0.006423264741897583, 降噪後的幀大小: 480
# VAD 概率: 0.006209433078765869, 降噪後的幀大小: 480
# VAD 概率: 0.004328250885009766, 降噪後的幀大小: 480
# VAD 概率: 0.0034634768962860107, 降噪後的幀大小: 480
# VAD 概率: 0.0031252801418304443, 降噪後的幀大小: 480
# VAD 概率: 0.002384871244430542, 降噪後的幀大小: 480
# VAD 概率: 0.002406567335128784, 降噪後的幀大小: 480
# VAD 概率: 0.002317577600479126, 降噪後的幀大小: 480
# VAD 概率: 0.0017592012882232666, 降噪後的幀大小: 480
# VAD 概率: 0.0020002424716949463, 降噪後的幀大小: 480
# VAD 概率: 0.001879274845123291, 降噪後的幀大小: 480
# VAD 概率: 0.0014903545379638672, 降噪後的幀大小: 480
# VAD 概率: 0.0013767778873443604, 降噪後的幀大小: 480
# VAD 概率: 0.0030837059020996094, 降噪後的幀大小: 480
# VAD 概率: 0.005256563425064087, 降噪後的幀大小: 480
# VAD 概率: 0.003034830093383789, 降噪後的幀大小: 480
# VAD 概率: 0.00420650839805603, 降噪後的幀大小: 480
# VAD 概率: 0.004396289587020874, 降噪後的幀大小: 480
# VAD 概率: 0.0069769322872161865, 降噪後的幀大小: 480
# VAD 概率: 0.014755159616470337, 降噪後的幀大小: 480
# VAD 概率: 0.010661661624908447, 降噪後的幀大小: 480
# VAD 概率: 0.008031994104385376, 降噪後的幀大小: 480
# VAD 概率: 0.003911435604095459, 降噪後的幀大小: 480
# VAD 概率: 0.004998713731765747, 降噪後的幀大小: 480
# VAD 概率: 0.002991318702697754, 降噪後的幀大小: 480
# VAD 概率: 0.0019673407077789307, 降噪後的幀大小: 480
# VAD 概率: 0.001524806022644043, 降噪後的幀大小: 480
# VAD 概率: 0.0016265511512756348, 降噪後的幀大小: 480
# VAD 概率: 0.0013079047203063965, 降噪後的幀大小: 480
# VAD 概率: 0.0009416341781616211, 降噪後的幀大小: 480
# VAD 概率: 0.0010573267936706543, 降噪後的幀大小: 480
# VAD 概率: 0.0009694695472717285, 降噪後的幀大小: 480
# VAD 概率: 0.0011869072914123535, 降噪後的幀大小: 480
# VAD 概率: 0.0024674832820892334, 降噪後的幀大小: 480
# VAD 概率: 0.006457388401031494, 降噪後的幀大小: 480
# VAD 概率: 0.09584358334541321, 降噪後的幀大小: 480
# VAD 概率: 0.39036330580711365, 降噪後的幀大小: 480
# VAD 概率: 0.6976211071014404, 降噪後的幀大小: 480
# VAD 概率: 0.7711590528488159, 降噪後的幀大小: 480
# VAD 概率: 0.7323973178863525, 降噪後的幀大小: 480
# VAD 概率: 0.4497995972633362, 降噪後的幀大小: 480
# VAD 概率: 0.1319928765296936, 降噪後的幀大小: 480
# VAD 概率: 0.045643359422683716, 降噪後的幀大小: 480
# VAD 概率: 0.0233498215675354, 降噪後的幀大小: 480
# VAD 概率: 0.01405477523803711, 降噪後的幀大小: 480
# VAD 概率: 0.007151246070861816, 降噪後的幀大小: 480
# VAD 概率: 0.004591792821884155, 降噪後的幀大小: 480
# VAD 概率: 0.004632860422134399, 降噪後的幀大小: 480
# VAD 概率: 0.005434900522232056, 降噪後的幀大小: 480
# VAD 概率: 0.00661805272102356, 降噪後的幀大小: 480
# VAD 概率: 0.008185118436813354, 降噪後的幀大小: 480
# VAD 概率: 0.004402875900268555, 降噪後的幀大小: 480
# VAD 概率: 0.004392772912979126, 降噪後的幀大小: 480
# VAD 概率: 0.0049953460693359375, 降噪後的幀大小: 480
# VAD 概率: 0.005082458257675171, 降噪後的幀大小: 480
# VAD 概率: 0.021612733602523804, 降噪後的幀大小: 480
# VAD 概率: 0.07912072539329529, 降噪後的幀大小: 480
# VAD 概率: 0.28852584958076477, 降噪後的幀大小: 480
# VAD 概率: 0.1119081974029541, 降噪後的幀大小: 480
# VAD 概率: 0.04398387670516968, 降噪後的幀大小: 480
# VAD 概率: 0.08367320895195007, 降噪後的幀大小: 480
# VAD 概率: 0.12852147221565247, 降噪後的幀大小: 480
# VAD 概率: 0.028441160917282104, 降噪後的幀大小: 480
# VAD 概率: 0.02719077467918396, 降噪後的幀大小: 480
# VAD 概率: 0.03686019778251648, 降噪後的幀大小: 480
# VAD 概率: 0.03549620509147644, 降噪後的幀大小: 480
# VAD 概率: 0.007776707410812378, 降噪後的幀大小: 480
# VAD 概率: 0.009430408477783203, 降噪後的幀大小: 480
# VAD 概率: 0.014939337968826294, 降噪後的幀大小: 480
# VAD 概率: 0.01459801197052002, 降噪後的幀大小: 480
# VAD 概率: 0.006736338138580322, 降噪後的幀大小: 480
# VAD 概率: 0.008212149143218994, 降噪後的幀大小: 480
# VAD 概率: 0.011330664157867432, 降噪後的幀大小: 480
# VAD 概率: 0.04960837960243225, 降噪後的幀大小: 480
# VAD 概率: 0.17795896530151367, 降噪後的幀大小: 480
# VAD 概率: 0.44805487990379333, 降噪後的幀大小: 480
# VAD 概率: 0.24182665348052979, 降噪後的幀大小: 480
# VAD 概率: 0.10864347219467163, 降噪後的幀大小: 480
# VAD 概率: 0.11180341243743896, 降噪後的幀大小: 480
# VAD 概率: 0.06286123394966125, 降噪後的幀大小: 480
# VAD 概率: 0.2947925627231598, 降噪後的幀大小: 480
# VAD 概率: 0.9078277945518494, 降噪後的幀大小: 480
# VAD 概率: 0.9832340478897095, 降噪後的幀大小: 480
# VAD 概率: 0.9915139675140381, 降噪後的幀大小: 480
# VAD 概率: 0.99683678150177, 降噪後的幀大小: 480
# VAD 概率: 0.9985127449035645, 降噪後的幀大小: 480
# VAD 概率: 0.9986710548400879, 降噪後的幀大小: 480
# VAD 概率: 0.9987387657165527, 降噪後的幀大小: 480
# VAD 概率: 0.9989981651306152, 降噪後的幀大小: 480
# VAD 概率: 0.9992877244949341, 降噪後的幀大小: 480
# VAD 概率: 0.9993807077407837, 降噪後的幀大小: 480
# VAD 概率: 0.999596357345581, 降噪後的幀大小: 480
# VAD 概率: 0.9998283386230469, 降噪後的幀大小: 480
# VAD 概率: 0.9998748302459717, 降噪後的幀大小: 480
# VAD 概率: 0.9999657869338989, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 0.9999977946281433, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 0.9999755620956421, 降噪後的幀大小: 480
# VAD 概率: 0.9999839663505554, 降噪後的幀大小: 480
# VAD 概率: 0.9999829530715942, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 1.0, 降噪後的幀大小: 480
# VAD 概率: 0.9999266266822815, 降噪後的幀大小: 480
# VAD 概率: 0.9998914003372192, 降噪後的幀大小: 480
# VAD 概率: 0.9998407363891602, 降噪後的幀大小: 480
# VAD 概率: 0.9998064041137695, 降噪後的幀大小: 480
# VAD 概率: 0.9993406534194946, 降噪後的幀大小: 480
# VAD 概率: 0.9966374635696411, 降噪後的幀大小: 480
# VAD 概率: 0.9972765445709229, 降噪後的幀大小: 480
# VAD 概率: 0.9977978467941284, 降噪後的幀大小: 480
# VAD 概率: 0.9969806671142578, 降噪後的幀大小: 480
# VAD 概率: 0.9958416223526001, 降噪後的幀大小: 480
# VAD 概率: 0.996153712272644, 降噪後的幀大小: 480
# VAD 概率: 0.995827317237854, 降噪後的幀大小: 480
# VAD 概率: 0.9937776327133179, 降噪後的幀大小: 480
# VAD 概率: 0.9846425652503967, 降噪後的幀大小: 480
# VAD 概率: 0.9974979162216187, 降噪後的幀大小: 480
# VAD 概率: 0.9993855953216553, 降噪後的幀大小: 480
# VAD 概率: 0.9998348951339722, 降噪後的幀大小: 480
# VAD 概率: 0.9998894333839417, 降噪後的幀大小: 480
# VAD 概率: 0.9998852014541626, 降噪後的幀大小: 480
# VAD 概率: 0.9999223947525024, 降噪後的幀大小: 480
# VAD 概率: 0.9999420642852783, 降噪後的幀大小: 480
# VAD 概率: 0.9999256134033203, 降噪後的幀大小: 480
# VAD 概率: 0.99991774559021, 降噪後的幀大小: 480
# VAD 概率: 0.9999091029167175, 降噪後的幀大小: 480
# VAD 概率: 0.9998804330825806, 降噪後的幀大小: 480
# VAD 概率: 0.9998676776885986, 降噪後的幀大小: 480
# VAD 概率: 0.9997324347496033, 降噪後的幀大小: 480
# VAD 概率: 0.9997108578681946, 降噪後的幀大小: 480
# VAD 概率: 0.9996637105941772, 降噪後的幀大小: 480
# VAD 概率: 0.9985134601593018, 降噪後的幀大小: 480
# VAD 概率: 0.9952368140220642, 降噪後的幀大小: 480
# VAD 概率: 0.9941766262054443, 降噪後的幀大小: 480
# VAD 概率: 0.9932229518890381, 降噪後的幀大小: 480
# VAD 概率: 0.995423436164856, 降噪後的幀大小: 480
# VAD 概率: 0.9941698312759399, 降噪後的幀大小: 480
# VAD 概率: 0.9948482513427734, 降噪後的幀大小: 480
# VAD 概率: 0.9965795278549194, 降噪後的幀大小: 480
# VAD 概率: 0.9963719248771667, 降噪後的幀大小: 480
# VAD 概率: 0.9950807094573975, 降噪後的幀大小: 480
# VAD 概率: 0.9952539205551147, 降噪後的幀大小: 480
# VAD 概率: 0.9925966858863831, 降噪後的幀大小: 480
# VAD 概率: 0.9905077219009399, 降噪後的幀大小: 480
# VAD 概率: 0.9808115363121033, 降噪後的幀大小: 480
# VAD 概率: 0.9706198573112488, 降噪後的幀大小: 480
# VAD 概率: 0.9832039475440979, 降噪後的幀大小: 480
# VAD 概率: 0.9810354709625244, 降噪後的幀大小: 480
# VAD 概率: 0.9904600381851196, 降噪後的幀大小: 480
# VAD 概率: 0.9944327473640442, 降噪後的幀大小: 480
# VAD 概率: 0.9960064888000488, 降噪後的幀大小: 480
# VAD 概率: 0.9982914924621582, 降噪後的幀大小: 480
# VAD 概率: 0.9994856119155884, 降噪後的幀大小: 480
# VAD 概率: 0.99969881772995, 降噪後的幀大小: 480
# VAD 概率: 0.9996821880340576, 降噪後的幀大小: 480
# VAD 概率: 0.9995167851448059, 降噪後的幀大小: 480
# VAD 概率: 0.9988902807235718, 降噪後的幀大小: 480
# VAD 概率: 0.9986077547073364, 降噪後的幀大小: 480
# VAD 概率: 0.9993890523910522, 降噪後的幀大小: 480
# VAD 概率: 0.9994916915893555, 降噪後的幀大小: 480
# VAD 概率: 0.9990719556808472, 降噪後的幀大小: 480
# VAD 概率: 0.997428297996521, 降噪後的幀大小: 480
# VAD 概率: 0.997344970703125, 降噪後的幀大小: 480
# VAD 概率: 0.9978736639022827, 降噪後的幀大小: 480
# VAD 概率: 0.9964953660964966, 降噪後的幀大小: 480
# VAD 概率: 0.997164249420166, 降噪後的幀大小: 480
# VAD 概率: 0.9941771030426025, 降噪後的幀大小: 480
# VAD 概率: 0.9925421476364136, 降噪後的幀大小: 480
# VAD 概率: 0.9956725239753723, 降噪後的幀大小: 480
# VAD 概率: 0.9890635013580322, 降噪後的幀大小: 480
# VAD 概率: 0.9805311560630798, 降噪後的幀大小: 480
# VAD 概率: 0.99091637134552, 降噪後的幀大小: 480
# VAD 概率: 0.9798459410667419, 降噪後的幀大小: 480
# VAD 概率: 0.9623369574546814, 降噪後的幀大小: 480
# VAD 概率: 0.9712928533554077, 降噪後的幀大小: 480
# VAD 概率: 0.9864901900291443, 降噪後的幀大小: 480
# VAD 概率: 0.980751097202301, 降噪後的幀大小: 480
# VAD 概率: 0.9911139011383057, 降噪後的幀大小: 480
# VAD 概率: 0.9948996305465698, 降噪後的幀大小: 480
# VAD 概率: 0.9945998191833496, 降噪後的幀大小: 480
# VAD 概率: 0.9946011304855347, 降噪後的幀大小: 480
# VAD 概率: 0.9945813417434692, 降噪後的幀大小: 480
# VAD 概率: 0.9959150552749634, 降噪後的幀大小: 480
# VAD 概率: 0.9971722364425659, 降噪後的幀大小: 480
# VAD 概率: 0.9989280700683594, 降噪後的幀大小: 480
# VAD 概率: 0.999494194984436, 降噪後的幀大小: 480
# VAD 概率: 0.999687135219574, 降噪後的幀大小: 480
# VAD 概率: 0.9995267391204834, 降噪後的幀大小: 480
# VAD 概率: 0.9995377659797668, 降噪後的幀大小: 480
# VAD 概率: 0.999819815158844, 降噪後的幀大小: 480
# VAD 概率: 0.9998608231544495, 降噪後的幀大小: 480
# VAD 概率: 0.9998683929443359, 降噪後的幀大小: 480
# VAD 概率: 0.9998722076416016, 降噪後的幀大小: 480
# VAD 概率: 0.9998778104782104, 降噪後的幀大小: 480
# VAD 概率: 0.9998795390129089, 降噪後的幀大小: 480
# VAD 概率: 0.9998418092727661, 降噪後的幀大小: 480
# VAD 概率: 0.999345064163208, 降噪後的幀大小: 480
# VAD 概率: 0.9957565069198608, 降噪後的幀大小: 480
# VAD 概率: 0.9932605624198914, 降噪後的幀大小: 480
# VAD 概率: 0.9835090637207031, 降噪後的幀大小: 480
# VAD 概率: 0.9858441352844238, 降噪後的幀大小: 480
# VAD 概率: 0.9853927493095398, 降噪後的幀大小: 480
# VAD 概率: 0.9927219152450562, 降噪後的幀大小: 480
# VAD 概率: 0.9965183734893799, 降噪後的幀大小: 480
# VAD 概率: 0.9975361824035645, 降噪後的幀大小: 480
# VAD 概率: 0.997804582118988, 降噪後的幀大小: 480
# VAD 概率: 0.9978681206703186, 降噪後的幀大小: 480
# VAD 概率: 0.9930996298789978, 降噪後的幀大小: 480
# VAD 概率: 0.9778937101364136, 降噪後的幀大小: 480
# VAD 概率: 0.9504199624061584, 降噪後的幀大小: 480
# VAD 概率: 0.9820531606674194, 降噪後的幀大小: 480
# VAD 概率: 0.9970536828041077, 降噪後的幀大小: 480
# VAD 概率: 0.9970645308494568, 降噪後的幀大小: 480
# VAD 概率: 0.9990558624267578, 降噪後的幀大小: 480
# VAD 概率: 0.9993078708648682, 降噪後的幀大小: 480
# VAD 概率: 0.9993141889572144, 降噪後的幀大小: 480
# VAD 概率: 0.9990419745445251, 降噪後的幀大小: 480
# VAD 概率: 0.9936222434043884, 降噪後的幀大小: 480
# VAD 概率: 0.9917210340499878, 降噪後的幀大小: 480
# VAD 概率: 0.9878950715065002, 降噪後的幀大小: 480
# VAD 概率: 0.9808241724967957, 降噪後的幀大小: 480
# VAD 概率: 0.9264755249023438, 降噪後的幀大小: 480
# VAD 概率: 0.8084591627120972, 降噪後的幀大小: 480
# VAD 概率: 0.8732144832611084, 降噪後的幀大小: 480
# VAD 概率: 0.8365375995635986, 降噪後的幀大小: 480
# VAD 概率: 0.9909608364105225, 降噪後的幀大小: 480
# VAD 概率: 0.9997192621231079, 降噪後的幀大小: 480
# VAD 概率: 0.9998760223388672, 降噪後的幀大小: 480
# VAD 概率: 0.9998916983604431, 降噪後的幀大小: 480
# VAD 概率: 0.9998601675033569, 降噪後的幀大小: 480
# VAD 概率: 0.9998568296432495, 降噪後的幀大小: 480
# VAD 概率: 0.9998775720596313, 降噪後的幀大小: 480
# VAD 概率: 0.9998623132705688, 降噪後的幀大小: 480
# VAD 概率: 0.999832272529602, 降噪後的幀大小: 480
# VAD 概率: 0.9997900724411011, 降噪後的幀大小: 480
# VAD 概率: 0.9995712041854858, 降噪後的幀大小: 480
# VAD 概率: 0.9994200468063354, 降噪後的幀大小: 480
# VAD 概率: 0.9995648860931396, 降噪後的幀大小: 480
# VAD 概率: 0.9994736909866333, 降噪後的幀大小: 480
# VAD 概率: 0.9988194704055786, 降噪後的幀大小: 480
# VAD 概率: 0.9992151260375977, 降噪後的幀大小: 480
# VAD 概率: 0.9986242055892944, 降噪後的幀大小: 480
# VAD 概率: 0.9971689581871033, 降噪後的幀大小: 480
# VAD 概率: 0.9973891973495483, 降噪後的幀大小: 480
# VAD 概率: 0.9876524209976196, 降噪後的幀大小: 480
# VAD 概率: 0.9838449954986572, 降噪後的幀大小: 480
# VAD 概率: 0.961856484413147, 降噪後的幀大小: 480
# VAD 概率: 0.8375194072723389, 降噪後的幀大小: 480
# VAD 概率: 0.5246210098266602, 降噪後的幀大小: 480
# VAD 概率: 0.33395856618881226, 降噪後的幀大小: 480
# VAD 概率: 0.19815710186958313, 降噪後的幀大小: 480
# VAD 概率: 0.09291884303092957, 降噪後的幀大小: 480
# VAD 概率: 0.07831448316574097, 降噪後的幀大小: 480
# VAD 概率: 0.11082756519317627, 降噪後的幀大小: 480
# VAD 概率: 0.09657806158065796, 降噪後的幀大小: 480
# VAD 概率: 0.05430474877357483, 降噪後的幀大小: 480
# VAD 概率: 0.03647494316101074, 降噪後的幀大小: 480
# VAD 概率: 0.016503900289535522, 降噪後的幀大小: 480
# VAD 概率: 0.007877141237258911, 降噪後的幀大小: 480
# VAD 概率: 0.008594781160354614, 降噪後的幀大小: 480
# VAD 概率: 0.006572604179382324, 降噪後的幀大小: 480
# VAD 概率: 0.002755463123321533, 降噪後的幀大小: 480
# VAD 概率: 0.0030831992626190186, 降噪後的幀大小: 480
# VAD 概率: 0.0019948482513427734, 降噪後的幀大小: 480
# VAD 概率: 0.002051740884780884, 降噪後的幀大小: 480
# VAD 概率: 0.0017020106315612793, 降噪後的幀大小: 480
# VAD 概率: 0.0013875961303710938, 降噪後的幀大小: 480
# VAD 概率: 0.001184612512588501, 降噪後的幀大小: 480
# VAD 概率: 0.0012898445129394531, 降噪後的幀大小: 480
# VAD 概率: 0.0013118982315063477, 降噪後的幀大小: 480
# VAD 概率: 0.0014808177947998047, 降噪後的幀大小: 480
# VAD 概率: 0.0010909736156463623, 降噪後的幀大小: 480
# VAD 概率: 0.0013396739959716797, 降噪後的幀大小: 480
# VAD 概率: 0.0020893514156341553, 降噪後的幀大小: 480
# VAD 概率: 0.0022392868995666504, 降噪後的幀大小: 480
# VAD 概率: 0.001278519630432129, 降噪後的幀大小: 480
# VAD 概率: 0.002470254898071289, 降噪後的幀大小: 480
# VAD 概率: 0.002122431993484497, 降噪後的幀大小: 480
# VAD 概率: 0.0012964308261871338, 降噪後的幀大小: 480
# VAD 概率: 0.0009861886501312256, 降噪後的幀大小: 480
# VAD 概率: 0.0007198750972747803, 降噪後的幀大小: 480
# VAD 概率: 0.0006816387176513672, 降噪後的幀大小: 480
# VAD 概率: 0.0010076463222503662, 降噪後的幀大小: 480
# VAD 概率: 0.001182645559310913, 降噪後的幀大小: 480
# VAD 概率: 0.000961601734161377, 降噪後的幀大小: 480
# VAD 概率: 0.0013085603713989258, 降噪後的幀大小: 480
# VAD 概率: 0.0012255609035491943, 降噪後的幀大小: 480
# VAD 概率: 0.0011650025844573975, 降噪後的幀大小: 480
# VAD 概率: 0.001394033432006836, 降噪後的幀大小: 480
# VAD 概率: 0.0009095966815948486, 降噪後的幀大小: 480
# VAD 概率: 0.0008665025234222412, 降噪後的幀大小: 480
# VAD 概率: 0.0009396672248840332, 降噪後的幀大小: 480
# VAD 概率: 0.0009399652481079102, 降噪後的幀大小: 480
# VAD 概率: 0.0013121962547302246, 降噪後的幀大小: 480
# VAD 概率: 0.001094520092010498, 降噪後的幀大小: 480
# VAD 概率: 0.0017381012439727783, 降噪後的幀大小: 480
# VAD 概率: 0.0010425448417663574, 降噪後的幀大小: 480
# VAD 概率: 0.00102311372756958, 降噪後的幀大小: 480
# VAD 概率: 0.0011089444160461426, 降噪後的幀大小: 480
# VAD 概率: 0.0015667378902435303, 降噪後的幀大小: 480
# VAD 概率: 0.001866459846496582, 降噪後的幀大小: 480
# VAD 概率: 0.001596212387084961, 降噪後的幀大小: 480
# VAD 概率: 0.0010401606559753418, 降噪後的幀大小: 480
# VAD 概率: 0.0014313161373138428, 降噪後的幀大小: 480
# VAD 概率: 0.0013908147811889648, 降噪後的幀大小: 480
# VAD 概率: 0.0013968050479888916, 降噪後的幀大小: 480
# VAD 概率: 0.0036687850952148438, 降噪後的幀大小: 480
# VAD 概率: 0.0037853121757507324, 降噪後的幀大小: 480
# VAD 概率: 0.0038169920444488525, 降噪後的幀大小: 480
# VAD 概率: 0.0019002556800842285, 降噪後的幀大小: 480
# VAD 概率: 0.0011861324310302734, 降噪後的幀大小: 480
# VAD 概率: 0.0008439123630523682, 降噪後的幀大小: 480
# VAD 概率: 0.0007708966732025146, 降噪後的幀大小: 480
# VAD 概率: 0.0006634891033172607, 降噪後的幀大小: 480
# VAD 概率: 0.0008674561977386475, 降噪後的幀大小: 480
# VAD 概率: 0.0009282231330871582, 降噪後的幀大小: 480
# 錄音結束

# %% [markdown]
# # 先用 pyrnnoise 再用 noisereduce 進行兩次降噪

# %%
import pyaudio
import noisereduce as nr
import numpy as np
import wave
from pyrnnoise import RNNoise

# 設置音頻流參數
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 44100
CHUNK = 1024
RECORD_SECONDS = 10
OUTPUT_FILENAME_ORIGINAL = "output_original.wav"
OUTPUT_FILENAME_REDUCED_1 = "output_reduced_1.wav"
OUTPUT_FILENAME_REDUCED_2 = "output_reduced_2.wav"

p = pyaudio.PyAudio()

# 打開音頻流
stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK)

print("開始錄音...")

frames_original = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames_original.append(data)

print("錄音結束...")

# 停止和關閉音頻流
stream.stop_stream()
stream.close()
p.terminate()

# 保存原始音頻數據到文件
wf_original = wave.open(OUTPUT_FILENAME_ORIGINAL, 'wb')
wf_original.setnchannels(CHANNELS)
wf_original.setsampwidth(p.get_sample_size(FORMAT))
wf_original.setframerate(RATE)
wf_original.writeframes(b''.join(frames_original))
wf_original.close()

print(f"原始音頻已保存到 {OUTPUT_FILENAME_ORIGINAL}")

# 初始化 RNNoise
rnnoise = RNNoise(RATE)

# 進行第一次降噪處理並保存降噪後的音頻數據到文件
wf_reduced_1 = wave.open(OUTPUT_FILENAME_REDUCED_1, 'wb')
wf_reduced_1.setnchannels(CHANNELS)
wf_reduced_1.setsampwidth(p.get_sample_size(FORMAT))
wf_reduced_1.setframerate(RATE)

for frame in frames_original:
    audio_data = np.frombuffer(frame, dtype=np.int16)
    denoised_chunks = []
    for vad_prob, denoised_chunk in rnnoise.process_chunk(audio_data):
        denoised_chunks.append(denoised_chunk)
    denoised_data = np.concatenate(denoised_chunks).astype(np.int16).tobytes()
    wf_reduced_1.writeframes(denoised_data)

wf_reduced_1.close()

print(f"第一次降噪後的音頻已保存到 {OUTPUT_FILENAME_REDUCED_1}")

# 讀取第一次降噪後的音頻數據
wf_reduced_1 = wave.open(OUTPUT_FILENAME_REDUCED_1, 'rb')
reduced_1_data = wf_reduced_1.readframes(wf_reduced_1.getnframes())
audio_data_reduced_1 = np.frombuffer(reduced_1_data, dtype=np.int16)
wf_reduced_1.close()

# 進行第二次降噪處理
reduced_noise_2 = nr.reduce_noise(y=audio_data_reduced_1, sr=RATE, prop_decrease=1.0, n_std_thresh_stationary=1.5)

# 保存第二次降噪後的音頻數據到文件
wf_reduced_2 = wave.open(OUTPUT_FILENAME_REDUCED_2, 'wb')
wf_reduced_2.setnchannels(CHANNELS)
wf_reduced_2.setsampwidth(p.get_sample_size(FORMAT))
wf_reduced_2.setframerate(RATE)
wf_reduced_2.writeframes(reduced_noise_2.tobytes())
wf_reduced_2.close()

print(f"第二次降噪後的音頻已保存到 {OUTPUT_FILENAME_REDUCED_2}")
# Out:
# 開始錄音...
# 錄音結束...
# 原始音頻已保存到 output_original.wav
# 第一次降噪後的音頻已保存到 output_reduced_1.wav
# 第二次降噪後的音頻已保存到 output_reduced_2.wav

# %% [markdown]
# # 先用 noisereduce 再用 pyrnnoise 進行兩次降噪

# %%
import pyaudio
import noisereduce as nr
import numpy as np
import wave
from pyrnnoise import RNNoise

# 設置音頻流參數
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 44100
CHUNK = 1024
RECORD_SECONDS = 10
OUTPUT_FILENAME_ORIGINAL = "output_original.wav"
OUTPUT_FILENAME_REDUCED_1 = "output_reduced_1.wav"
OUTPUT_FILENAME_REDUCED_2 = "output_reduced_2.wav"

p = pyaudio.PyAudio()

# 打開音頻流
stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK)

print("開始錄音...")

frames_original = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames_original.append(data)

print("錄音結束...")

# 停止和關閉音頻流
stream.stop_stream()
stream.close()
p.terminate()

# 保存原始音頻數據到文件
wf_original = wave.open(OUTPUT_FILENAME_ORIGINAL, 'wb')
wf_original.setnchannels(CHANNELS)
wf_original.setsampwidth(p.get_sample_size(FORMAT))
wf_original.setframerate(RATE)
wf_original.writeframes(b''.join(frames_original))
wf_original.close()

print(f"原始音頻已保存到 {OUTPUT_FILENAME_ORIGINAL}")

# 進行第一次降噪處理並保存降噪後的音頻數據到文件
wf_reduced_1 = wave.open(OUTPUT_FILENAME_REDUCED_1, 'wb')
wf_reduced_1.setnchannels(CHANNELS)
wf_reduced_1.setsampwidth(p.get_sample_size(FORMAT))
wf_reduced_1.setframerate(RATE)

for frame in frames_original:
    audio_data = np.frombuffer(frame, dtype=np.int16)
    reduced_noise = nr.reduce_noise(y=audio_data, sr=RATE, prop_decrease=1.0, n_std_thresh_stationary=1.5)
    wf_reduced_1.writeframes(reduced_noise.tobytes())

wf_reduced_1.close()

print(f"第一次降噪後的音頻已保存到 {OUTPUT_FILENAME_REDUCED_1}")

# 讀取第一次降噪後的音頻數據
wf_reduced_1 = wave.open(OUTPUT_FILENAME_REDUCED_1, 'rb')
reduced_1_data = wf_reduced_1.readframes(wf_reduced_1.getnframes())
audio_data_reduced_1 = np.frombuffer(reduced_1_data, dtype=np.int16)
wf_reduced_1.close()

# 初始化 RNNoise
rnnoise = RNNoise(RATE)

# 進行第二次降噪處理並保存降噪後的音頻數據到文件
wf_reduced_2 = wave.open(OUTPUT_FILENAME_REDUCED_2, 'wb')
wf_reduced_2.setnchannels(CHANNELS)
wf_reduced_2.setsampwidth(p.get_sample_size(FORMAT))
wf_reduced_2.setframerate(RATE)

denoised_chunks = []
for vad_prob, denoised_chunk in rnnoise.process_chunk(audio_data_reduced_1):
    denoised_chunks.append(denoised_chunk)
denoised_data = np.concatenate(denoised_chunks).astype(np.int16).tobytes()
wf_reduced_2.writeframes(denoised_data)

wf_reduced_2.close()

print(f"第二次降噪後的音頻已保存到 {OUTPUT_FILENAME_REDUCED_2}")
# Out:
# 開始錄音...
# 錄音結束...
# 原始音頻已保存到 output_original.wav
# 第一次降噪後的音頻已保存到 output_reduced_1.wav
# 第二次降噪後的音頻已保存到 output_reduced_2.wav

# %% [markdown]
# # 計算路徑下 wav總時長

# %%
import wave
import os

def get_wav_duration(file_path):
    with wave.open(file_path, 'rb') as wf:
        frames = wf.getnframes()
        rate = wf.getframerate()
        duration = frames / float(rate)
        return duration

def calculate_total_duration(folder_path):
    total_duration = 0.0
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.wav'):
            file_path = os.path.join(folder_path, file_name)
            duration = get_wav_duration(file_path)
            total_duration += duration
            print(f"{file_name}: {duration:.2f} seconds")
    return total_duration

folder_path = 'C:\\Users\\User\\Documents\\work\\GPT-SoVITS-beta0217\\DATA\\Joneshong\\slicer'  # 替換為你的資料夾路徑
total_duration = calculate_total_duration(folder_path)
print(f"Total duration: {total_duration:.2f} seconds")
# Out:
# vocal_0.wav.reformatted.wav_10.wav_0000011520_0000141760.wav: 4.07 seconds
# vocal_0.wav.reformatted.wav_10.wav_0000141760_0000270720.wav: 4.03 seconds
# vocal_0.wav.reformatted.wav_10.wav_0000276160_0000393280.wav: 3.66 seconds
# vocal_0.wav.reformatted.wav_10.wav_0000393280_0000523520.wav: 4.07 seconds
# vocal_0.wav.reformatted.wav_10.wav_0000530240_0000690560.wav: 5.01 seconds
# vocal_0.wav.reformatted.wav_10.wav_0000690560_0000813760.wav: 3.85 seconds
# vocal_0.wav.reformatted.wav_10.wav_0000813760_0000914560.wav: 3.15 seconds
# vocal_1.wav.reformatted.wav_10.wav_0000011200_0000160640.wav: 4.67 seconds
# vocal_1.wav.reformatted.wav_10.wav_0000160640_0000345280.wav: 5.77 seconds
# vocal_1.wav.reformatted.wav_10.wav_0000345280_0000503680.wav: 4.95 seconds
# vocal_1.wav.reformatted.wav_10.wav_0000503680_0000701120.wav: 6.17 seconds
# vocal_2.wav.reformatted.wav_10.wav_0000006400_0000119040.wav: 3.52 seconds
# vocal_2.wav.reformatted.wav_10.wav_0000121280_0000241280.wav: 3.75 seconds
# vocal_2.wav.reformatted.wav_10.wav_0000256320_0000415680.wav: 4.98 seconds
# vocal_2.wav.reformatted.wav_10.wav_0000415680_0000579520.wav: 5.12 seconds
# vocal_2.wav.reformatted.wav_10.wav_0000579520_0000715200.wav: 4.24 seconds
# vocal_2.wav.reformatted.wav_10.wav_0000715200_0000906880.wav: 5.99 seconds
# vocal_2.wav.reformatted.wav_10.wav_0000916800_0001032320.wav: 3.61 seconds
# vocal_2.wav.reformatted.wav_10.wav_0001032320_0001149440.wav: 3.66 seconds
# vocal_2.wav.reformatted.wav_10.wav_0001149440_0001310400.wav: 5.03 seconds
# vocal_2.wav.reformatted.wav_10.wav_0001347200_0001509760.wav: 5.08 seconds
# vocal_2.wav.reformatted.wav_10.wav_0001509760_0001690560.wav: 5.65 seconds
# vocal_2.wav.reformatted.wav_10.wav_0001690560_0001873600.wav: 5.72 seconds
# vocal_2.wav.reformatted.wav_10.wav_0001873600_0002016640.wav: 4.47 seconds
# vocal_2.wav.reformatted.wav_10.wav_0002016640_0002217920.wav: 6.29 seconds
# vocal_2.wav.reformatted.wav_10.wav_0002234880_0002357440.wav: 3.83 seconds
# vocal_2.wav.reformatted.wav_10.wav_0002374400_0002529600.wav: 4.85 seconds
# vocal_2.wav.reformatted.wav_10.wav_0002529600_0002630720.wav: 3.16 seconds
# vocal_2.wav.reformatted.wav_10.wav_0002654080_0002780160.wav: 3.94 seconds
# vocal_2.wav.reformatted.wav_10.wav_0002780160_0002847360.wav: 2.10 seconds
# vocal_3.wav.reformatted.wav_10.wav_0000001920_0000126080.wav: 3.88 seconds
# vocal_3.wav.reformatted.wav_10.wav_0000126080_0000322240.wav: 6.13 seconds
# vocal_3.wav.reformatted.wav_10.wav_0000322560_0000453760.wav: 4.10 seconds
# vocal_3.wav.reformatted.wav_10.wav_0000453760_0000591360.wav: 4.30 seconds
# vocal_3.wav.reformatted.wav_10.wav_0000591360_0000758080.wav: 5.21 seconds
# vocal_3.wav.reformatted.wav_10.wav_0000758080_0000887360.wav: 4.04 seconds
# vocal_3.wav.reformatted.wav_10.wav_0000887360_0001100800.wav: 6.67 seconds
# vocal_3.wav.reformatted.wav_10.wav_0001100800_0001251840.wav: 4.72 seconds
# vocal_4.wav.reformatted.wav_10.wav_0000019520_0000142080.wav: 3.83 seconds
# vocal_4.wav.reformatted.wav_10.wav_0000142080_0000307840.wav: 5.18 seconds
# vocal_4.wav.reformatted.wav_10.wav_0000307840_0000467840.wav: 5.00 seconds
# vocal_4.wav.reformatted.wav_10.wav_0000469760_0000626240.wav: 4.89 seconds
# vocal_4.wav.reformatted.wav_10.wav_0000626240_0000750400.wav: 3.88 seconds
# vocal_4.wav.reformatted.wav_10.wav_0000750400_0000913600.wav: 5.10 seconds
# vocal_4.wav.reformatted.wav_10.wav_0000913600_0001031680.wav: 3.69 seconds
# vocal_4.wav.reformatted.wav_10.wav_0001043840_0001151680.wav: 3.37 seconds
# vocal_5.wav.reformatted.wav_10.wav_0000009600_0000197440.wav: 5.87 seconds
# vocal_5.wav.reformatted.wav_10.wav_0000197440_0000379840.wav: 5.70 seconds
# vocal_5.wav.reformatted.wav_10.wav_0000379840_0000519680.wav: 4.37 seconds
# vocal_5.wav.reformatted.wav_10.wav_0000537920_0000669120.wav: 4.10 seconds
# vocal_5.wav.reformatted.wav_10.wav_0000669120_0000869760.wav: 6.27 seconds
# vocal_5.wav.reformatted.wav_10.wav_0000869760_0001046720.wav: 5.53 seconds
# vocal_5.wav.reformatted.wav_10.wav_0001046720_0001192960.wav: 4.57 seconds
# vocal_5.wav.reformatted.wav_10.wav_0001192960_0001280960.wav: 2.75 seconds
# vocal_6.wav.reformatted.wav_10.wav_0000008320_0000162240.wav: 4.81 seconds
# vocal_6.wav.reformatted.wav_10.wav_0000162240_0000283200.wav: 3.78 seconds
# vocal_6.wav.reformatted.wav_10.wav_0000283200_0000446400.wav: 5.10 seconds
# vocal_6.wav.reformatted.wav_10.wav_0000456960_0000632640.wav: 5.49 seconds
# vocal_6.wav.reformatted.wav_10.wav_0000632640_0000784960.wav: 4.76 seconds
# vocal_6.wav.reformatted.wav_10.wav_0000784960_0000944640.wav: 4.99 seconds
# vocal_6.wav.reformatted.wav_10.wav_0000944640_0001100800.wav: 4.88 seconds
# Total duration: 281.35 seconds

# %%
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift
import numpy as np

augment = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.5),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
    Shift(p=0.5),
])

# 生成2秒钟的虚拟音频以便示例
samples = np.random.uniform(low=-0.2, high=0.2, size=(32000,)).astype(np.float32)

# 对音频数据进行增强/变换/扰动
augmented_samples = augment(samples=samples, sample_rate=16000)

# %%
import pyaudio
import wave
from pyrnnoise import RNNoise

# 設置音頻流參數
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 44100
CHUNK = 1024
RECORD_SECONDS = 10
OUTPUT_FILENAME_ENHANCED = "output_enhanced.wav"

p = pyaudio.PyAudio()

# 打開音頻流
stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK)

print("開始錄音...")

frames = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data)

print("錄音結束...")

# 停止和關閉音頻流
stream.stop_stream()
stream.close()
p.terminate()

# 初始化 RNNoise
rnnoise = RNNoise(RATE)

# 進行人聲增強
enhanced_frames = []
for frame in frames:
    audio_data = np.frombuffer(frame, dtype=np.int16)
    denoised_chunks = []
    for vad_prob, denoised_chunk in rnnoise.process_chunk(audio_data):
        denoised_chunks.append(denoised_chunk)
    denoised_data = np.concatenate(denoised_chunks).astype(np.int16).tobytes()
    enhanced_frames.append(denoised_data)

# 保存增強後的音頻數據到文件
wf_enhanced = wave.open(OUTPUT_FILENAME_ENHANCED, 'wb')
wf_enhanced.setnchannels(CHANNELS)
wf_enhanced.setsampwidth(p.get_sample_size(FORMAT))
wf_enhanced.setframerate(RATE)
wf_enhanced.writeframes(b''.join(enhanced_frames))
wf_enhanced.close()

print(f"增強後的音頻已保存到 {OUTPUT_FILENAME_ENHANCED}")
# Out:
# 開始錄音...
# 錄音結束...
# 增強後的音頻已保存到 output_enhanced.wav
# 在目前儲存格或上一個儲存格中執行程式碼時，Kernel 已損毀。
#
# 請檢閱儲存格中的程式碼，找出失敗的可能原因。
#
# 如需詳細資訊，請按一下<a href='https://aka.ms/vscodeJupyterKernelCrash'>這裡</a>。
#
# 如需詳細資料，請檢視 Jupyter <a href='command:jupyter.viewOutput'>記錄</a>。
